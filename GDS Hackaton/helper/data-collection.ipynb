# %%
import pandas as pd
import csv

# %%
data = pd.read_csv('../datasets/attractions/attractions_data_en.csv')

# %%
data.head(5)
# Out:
#                                            Title  \
# 0              Ethno-memorial complex «Atameken»
# 1         «Nur-Alem» Future Energy Museum (EXPO)
# 2               Theater of animatronics «Jungle»
# 3         The Palace of Peace and Reconciliation
# 4  National Museum of the Republic of Kazakhstan
#
#                              Address        Phone Number  \
# 0   Астана, Коргалжинское шоссе, 2/1  +7 (7172) 79-04-39
# 1              Астана, Орынбор , 55.  +7 (7172) 79-04-39
# 2  г. Астана, Коргалжинское шоссе, 2  +7 (7172) 79-04-39
# 3    Астана, проспект Тауелсiздiк 57  +7 (7172) 79-04-39
# 4        Астана, пр. Тәуелсіздік, 54  +7 (7172) 79-04-39
#
#                                          Description  \
# 0  The ethno-memorial complex “Map of Kazakhstan ...
# 1  Nur-Alem is the main symbol of EXPO Nur-Sultan...
# 2  The idea of creating a one-of-a-kind dinosaur ...
# 3  The city of Astana can boast a number of impre...
# ...

# %%
types = []

for idx in data.index:
    types.append(data['Title'][idx])

# %%
index = 0

title = data['Title'][index]
address = data['Address'][index]
phone = data['Phone Number'][index]
link = data['Link'][index]
description = data['Description'][index]

input = f"Напиши мне 40 вопросов и ответов в Python формате ['question': 'answer'] используя эти данные:\n\nTitle: {title}\nAddress: {address}\nPhone Number: {phone}\nLink: {link}\nDescription: {description}"

print(input)
# Out:
# Напиши мне 40 вопросов и ответов в Python формате ['question': 'answer'] используя эти данные:
#
# Title: Ethno-memorial complex «Atameken»
# Address: Астана, Коргалжинское шоссе, 2/1
# Phone Number: +7 (7172) 79-04-39
# Link: https://astana.citypass.kz/en/2018/07/17/etno-memorialnyiy-kompleks-atameken/
# ...

# %%
dataset_15 = [
    {
        "question": "What is the title of the museum?",
        "answer": "Military-historical museum of the Armed Forces of the Republic of Kazakhstan."
    },
    {
        "question": "Where is the museum located?",
        "answer": "Астана, пр. Республики, 2."
    },
    {
        "question": "What is the phone number of the museum?",
        "answer": "+7 (7172) 44‒26‒19"
    },
    {
        "question": "What are the working hours of the museum?",
        "answer": "Пн: технический день, Вт-Вс: с 10:00 до 18:00"
    },
    {
        "question": "What is the link to the museum's website?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/voenno-istoricheskiy-muzey-vooruzhennyih-sil-respubliki-kazahstan/"
    },
    {
        "question": "Can you provide a brief description of the museum?",
        "answer": "The military history Museum has unique halls that complement the structural and architectural appearance of the building with their expositions. In the Museum You are greeted by the hall of Armed forces of Kazakhstan, the hall for periodic exhibitions, the hall is “Ancient” – XIX century, the hall of the military history of the XX century, the hall of weapons of the XX-XXI century, the hall of fine arts and atrium “History of military Affairs of Kazakhstan.”In each hall of the building of the Military history Museum of the Republic of Kazakhstan there is a spirit of old or present history, which the organizers were able to recreate with the help of technical means. The variety of forms in which the Museum tells visitors the history of time is striking. It seems that all the exhibits will come to life a little more, and will talk to the guests. Mirror canvases of stands dedicated to the formation of the Armed Forces of the Republic of Kazakhstan reflect those who made an impossible contribution to the development of these forces. The military history Museum is located in the former Presidential center of culture of the Republic of Kazakhstan.The military history Museum of the armed forces has collected about 6000 exhibits, including rare and especially valuable historical and cultural monuments, ammunition of Kazakh soldiers from the stone age to the present day. Weapons and Paintings, historical documents and photographs of events. Stands of military branches, events and famous personalities.The military history Museum in Astana has great differences from other museums of this nature. Its main feature is the presence of a highlight-LED TVs with a wide multimedia screen. On these screens, visitors to the Museum can see truly exciting footage from the great Patriotic war, the period of the rule of the Kazakh khans, as well as modern military events from around the world.Here you can touch the history in a literal sense, because there you can not only see a lot, but also touch and listen to it. All items that are located in the Museum building tell about the military history of the Republic of Kazakhstan, starting from ancient times and ending with the present.The military history Museum of the armed forces of the Republic of Kazakhstan at the time of its creation was like a white sheet, without a single historically important exhibit. The creators had to spend a lot of time, effort and resources to recreate the idea. And the result exceeds all expectations, because today the military history Museum in Kazakhstan allows anyone to feel pride in the historical past and present of Kazakhstan."
    },
    {
        "question": "How many exhibits does the museum have?",
        "answer": "About 6000 exhibits."
    },
    {
        "question": "What types of exhibits are present in the museum?",
        "answer": "The exhibits include rare and especially valuable historical and cultural monuments, ammunition of Kazakh soldiers from the stone age to the present day, weapons, paintings, historical documents, photographs of events, stands of military branches, events, and famous personalities."
    },
    {
        "question": "What are the main features of the museum?",
        "answer": "The main feature is the presence of LED TVs with a wide multimedia screen, showcasing exciting footage from various historical periods and modern military events."
    },
    {
        "question": "What is the historical scope covered by the museum?",
        "answer": "The museum covers the military history of Kazakhstan from ancient times to the present."
    },
    {
        "question": "Where was the military history museum located before?",
        "answer": "The military history museum is located in the former Presidential center of culture of the Republic of Kazakhstan."
    },
    {
        "question": "What can visitors do at the museum?",
        "answer": "Visitors can not only see exhibits but also touch and listen to them, experiencing the military history of Kazakhstan firsthand."
    },
    {
        "question": "What are the different halls present in the museum?",
        "answer": "The museum has halls dedicated to the Armed Forces of Kazakhstan, periodic exhibitions, the ancient era (XIX century), the military history of the XX century, weapons of the XX-XXI century, fine arts, and the atrium showcasing the history of military affairs of Kazakhstan."
    },
    {
        "question": "How does the museum use technical means to recreate history?",
        "answer": "Organizers use technical means in each hall to recreate the spirit of old or present history, making the exhibits come to life and engage with visitors."
    },
    {
        "question": "What historical periods are covered by the multimedia screens?",
        "answer": "The multimedia screens showcase footage from the great Patriotic war, the period of the rule of the Kazakh khans, as well as modern military events from around the world."
    },
    {
        "question": "What was the condition of the museum at its creation?",
        "answer": "At its creation, the museum had no historically important exhibits, requiring the creators to spend significant time, effort, and resources to establish its collections."
    },
    {
        "question": "What role does the museum play in preserving Kazakhstan's historical past?",
        "answer": "The museum allows anyone to feel pride in the historical past and present of Kazakhstan by showcasing its military history from ancient times to the present."
    },
    {
        "question": "What distinguishes the museum from other military history museums?",
        "answer": "The presence of LED TVs with a wide multimedia screen, allowing visitors to engage with exciting footage and experience history firsthand, sets the museum apart."
    },
    {
        "question": "How many halls are dedicated to specific time periods in history?",
        "answer": "The museum has halls dedicated to the ancient era (XIX century) and the military history of the XX century."
    },
    {
        "question": "What types of multimedia are available for visitors?",
        "answer": "Visitors can access LED TVs with a wide multimedia screen, showcasing various historical and modern military events."
    },
    {
        "question": "What is the significance of the atrium in the museum?",
        "answer": "The atrium showcases the history of military affairs of Kazakhstan, providing visitors with insights into the country's military heritage."
    },
    {
        "question": "How does the museum make history interactive for visitors?",
        "answer": "Visitors can not only see exhibits but also touch and listen to them, providing an interactive experience of Kazakhstan's military history."
    }
]

# %%
dataset_14 = [
    {
        "question": "What is the title of the center?",
        "answer": "Nazarbayev Center."
    },
    {
        "question": "Where is the center located?",
        "answer": "Астана, ул. Алихана Букейханова, 10."
    },
    {
        "question": "What is the phone number of the center?",
        "answer": "+7 (7172) 70‒83‒04"
    },
    {
        "question": "What are the working hours of the center?",
        "answer": "Пн: технический день, Вт-Вс: с 10:00 до 18:00"
    },
    {
        "question": "What is the link to the center's website?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/prezidentskaya-biblioteka/"
    },
    {
        "question": "Can you describe the architecture of the center?",
        "answer": "The original architectural appearance of the Nazarbayev Center, designed by British architect Norman Foster, symbolizes the vitality of modern Kazakhstan. It resembles a huge eye reaching into the sky."
    },
    {
        "question": "What is the total area of the center?",
        "answer": "The center has an area of more than 28 thousand square meters."
    },
    {
        "question": "How many floors does the center have?",
        "answer": "The center consists of 9 floors."
    },
    {
        "question": "What is the total storage capacity of the library?",
        "answer": "The total storage capacity of the library is designed for 460 thousand units, including closed funds – up to 200 thousand units."
    },
    {
        "question": "What is the technical uniqueness of the Nazarbayev center?",
        "answer": "The special roof structure allows the span diameter to reach 81 meters."
    },
    {
        "question": "What is the main feature of the interior layout of the complex?",
        "answer": "The entire interior layout is centered around a Central atrium with a diameter of 26 meters and an area of 535 square meters."
    },
    {
        "question": "What are the information platforms of the Foundation of the First President of the Republic of Kazakhstan?",
        "answer": "The Museum and library, which are part of the Nazarbayev Center."
    },
    {
        "question": "What type of information can visitors find at the center?",
        "answer": "Visitors can find comprehensive information about the activities of the First President of the Republic of Kazakhstan. Access to resources is provided through modern technologies and innovative multimedia capabilities."
    },
    {
        "question": "What is the main task of the Nazarbayev center?",
        "answer": "The main task is the formation and subsequent improvement of a unified and active information space for the study and promotion of the history of statehood in Kazakhstan, as well as support for the historical heritage of the head of state."
    },
    {
        "question": "What are the activities aimed at by the center?",
        "answer": "The center's activities are aimed at strengthening the principles of patriotism and civic identity, developing international cooperation of the Republic in political, humanitarian, social, and other fields, and updating knowledge about Kazakhstan and its role in the world community."
    },
    {
        "question": "What is required for access to the center?",
        "answer": "An original identity document must be presented."
    },
    {
        "question": "What do tourists note about the format of the Museum and library?",
        "answer": "Tourists note the non-traditional format of the Museum and library, where access to resources is provided through modern technologies and innovative multimedia capabilities."
    },
    {
        "question": "What role does the center play in promoting patriotism and civic identity?",
        "answer": "The center plays a role in strengthening the principles of patriotism and civic identity through its activities."
    },
    {
        "question": "How does the center contribute to international cooperation?",
        "answer": "The center contributes to the development of international cooperation of the Republic in political, humanitarian, social, and other fields."
    },
    {
        "question": "What is the purpose of updating knowledge about Kazakhstan?",
        "answer": "The purpose is to update knowledge about Kazakhstan and its role in the world community."
    },
    {
        "question": "How does the center support the historical heritage of the head of state?",
        "answer": "The center supports the historical heritage of the head of state by providing comprehensive information about his activities."
    },
    {
        "question": "What is the diameter of the Central atrium?",
        "answer": "The Central atrium has a diameter of 26 meters."
    },
    {
        "question": "What is the area of the Central atrium?",
        "answer": "The area of the Central atrium is 535 square meters."
    },
    {
        "question": "What is the main focus of the center's activities?",
        "answer": "The main focus is on the study and promotion of the history of statehood in Kazakhstan."
    },
    {
        "question": "How does the center use modern technologies?",
        "answer": "The center uses modern technologies to provide access to resources and present information in innovative ways."
    },
    {
        "question": "What visual material can visitors study at the center?",
        "answer": "Visitors can study various visual materials related to the activities of the First President of the Republic of Kazakhstan."
    },
    {
        "question": "What is the symbolic significance of the architecture?",
        "answer": "The architecture symbolizes the vitality of modern Kazakhstan."
    },
    {
        "question": "How does the center contribute to the study of Kazakhstan's statehood?",
        "answer": "The center contributes to the study and promotion of the history of statehood in Kazakhstan through its activities."
    },
    {
        "question": "What is the area of the roof structure?",
        "answer": "The roof structure has a span diameter of 81 meters."
    },
    {
        "question": "What is the purpose of the information platforms?",
        "answer": "The purpose of the information platforms is to provide comprehensive information about the activities of the First President of the Republic of Kazakhstan."
    },
    {
        "question": "How does the center engage visitors with its resources?",
        "answer": "The center engages visitors through modern technologies and innovative multimedia capabilities, allowing them to study visual and informational material."
    },
    {
        "question": "What is the significance of the total storage capacity of the library?",
        "answer": "The total storage capacity allows for the storage of a large number of units, including closed funds."
    },
    {
        "question": "How does the center contribute to the promotion of Kazakhstan's historical heritage?",
        "answer": "The center contributes to the promotion of Kazakhstan's historical heritage by supporting the historical heritage of the head of state and providing access to comprehensive information."
    },
    {
        "question": "What is the primary goal of the center's activities?",
        "answer": "The primary goal is the formation and improvement of a unified and active information space for the study and promotion of Kazakhstan's history."
    },
    {
        "question": "What do visitors appreciate about the center?",
        "answer": "Visitors appreciate the non-traditional format of the Museum and library, as well as the comprehensive information provided through modern technologies."
    },
    {
        "question": "How does the center contribute to the development of patriotism?",
        "answer": "The center contributes to the development of patriotism by strengthening principles of civic identity and promoting knowledge about Kazakhstan."
    },
    {
        "question": "What is the role of the multimedia capabilities?",
        "answer": "The multimedia capabilities enable visitors to access resources and study information in innovative ways."
    },
    {
        "question": "What is the layout centered around?",
        "answer": "The layout is centered around a Central atrium."
    },
    {
        "question": "How does the center support civic identity?",
        "answer": "The center supports civic identity through its activities aimed at strengthening principles of patriotism."
    },
    {
        "question": "What are the main components of the Nazarbayev center?",
        "answer": "The main components are the Museum and library."
    },
    {
        "question": "What is the focus of the museum's collections?",
        "answer": "The focus of the museum's collections is on the activities of the First President of the Republic of Kazakhstan."
    }
]

# %%
dataset_13 = [
    {
        "question": "What is the title of the museum?",
        "answer": "Museum of the First President of Kazakhstan."
    },
    {
        "question": "Where is the museum located?",
        "answer": "Астана, ул. Бейбитшилик, 11."
    },
    {
        "question": "What is the phone number of the museum?",
        "answer": "+7 (7172) 69‒30‒41"
    },
    {
        "question": "What are the working hours of the museum?",
        "answer": "Пн: технический день, Вт-Вс: с 10:00 до 18:00"
    },
    {
        "question": "What is the link to the museum's website?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/muzey-pervogo-prezidenta-rk-2/"
    },
    {
        "question": "Can you describe the museum's focus?",
        "answer": "The Museum reflects the modern history of Kazakhstan and emphasizes the historical role of the First President in building an independent and democratic state."
    },
    {
        "question": "What types of tours does the museum offer?",
        "answer": "The museum offers sightseeing and thematic tours in Kazakh, Russian, and English for all categories of visitors."
    },
    {
        "question": "What role has the museum established for itself?",
        "answer": "The Museum of the First President in Nur-Sultan has established itself as an authoritative research, educational, and cultural center, becoming one of the attractions of the capital."
    },
    {
        "question": "How many Museum exhibits does the museum have?",
        "answer": "The museum has more than 40,000 Museum exhibits."
    },
    {
        "question": "What is notable about the collection?",
        "answer": "The collection continues to be replenished with new copies, and visitors are particularly interested in the personal awards of the head of state, including insignia from various foreign organizations and different countries, awards from the Soviet Union, and modern Kazakhstan."
    },
    {
        "question": "What types of exhibitions does the museum hold?",
        "answer": "The museum periodically holds exhibitions dedicated to art, craft, scientific projects, and other activities. One notable exhibition is called 'Country and World', which showcases about 150 items collected from three dozen countries."
    },
    {
        "question": "What do the exhibits of the museum represent?",
        "answer": "The exhibits represent sculptural and figurative objects, many of which are gifts from heads of foreign countries, politicians, international companies, foundations, and organizations."
    },
    {
        "question": "How can visitors access the museum?",
        "answer": "Visitors need to go to the Central part of the city of Astana. They can visit the museum as part of a tour group or separately, following their own route."
    },
    {
        "question": "What languages are tours offered in?",
        "answer": "Tours are offered in Kazakh, Russian, and English."
    },
    {
        "question": "What is the significance of the Museum of the First President in Kazakhstan?",
        "answer": "The museum serves as an authoritative research, educational, and cultural center, emphasizing the historical role of the First President in building the country."
    },
    {
        "question": "What is the focus of the museum's collections?",
        "answer": "The focus is on reflecting the modern history of Kazakhstan and the role of the First President in its development."
    },
    {
        "question": "What is the purpose of the sightseeing tours?",
        "answer": "The purpose is to provide visitors with an overview of the museum's exhibits and its significance in Kazakhstan's history."
    },
    {
        "question": "How does the museum contribute to cultural exchange?",
        "answer": "The museum holds exhibitions featuring items from various countries, fostering cultural exchange and understanding."
    },
    {
        "question": "What types of items are exhibited in the 'Country and World' exhibition?",
        "answer": "The exhibition showcases sculptural and figurative objects collected from three dozen countries."
    },
    {
        "question": "What makes the museum a popular attraction?",
        "answer": "The museum's authoritative status as a research, educational, and cultural center, along with its diverse exhibitions and extensive collection, makes it a popular attraction."
    },
    {
        "question": "What is the primary focus of the museum's educational activities?",
        "answer": "The primary focus is on educating visitors about the modern history of Kazakhstan and the role of the First President."
    },
    {
        "question": "How does the museum engage with visitors?",
        "answer": "The museum offers tours in multiple languages and holds thematic exhibitions to engage visitors with its exhibits."
    },
    {
        "question": "What is the main theme of the 'Country and World' exhibition?",
        "answer": "The main theme is to showcase items from different countries, promoting cultural exchange and understanding."
    },
    {
        "question": "What types of awards are displayed in the museum?",
        "answer": "The museum displays personal awards of the head of state, including insignia from various foreign organizations and countries, awards from the Soviet Union, and modern Kazakhstan."
    },
    {
        "question": "How does the museum's collection continue to grow?",
        "answer": "The collection continues to grow with new additions, ensuring that the museum remains relevant and engaging for visitors."
    },
    {
        "question": "What is the significance of the museum's location?",
        "answer": "The museum's location in the Central part of Astana makes it easily accessible to visitors."
    },
    {
        "question": "What is the role of the museum in preserving Kazakhstan's history?",
        "answer": "The museum preserves Kazakhstan's modern history and highlights the role of the First President in shaping the country."
    },
    {
        "question": "What languages are the museum's exhibitions presented in?",
        "answer": "Exhibitions are presented in multiple languages, including Kazakh, Russian, and English, to cater to diverse audiences."
    },
    {
        "question": "What is the significance of the museum's thematic tours?",
        "answer": "Thematic tours offer visitors a deeper insight into specific aspects of the museum's collections and their historical significance."
    },
    {
        "question": "How does the museum contribute to promoting cultural understanding?",
        "answer": "The museum promotes cultural understanding by showcasing items from various countries and fostering dialogue and exchange among visitors."
    },
    {
        "question": "What distinguishes the museum from other cultural institutions in Astana?",
        "answer": "The museum's focus on modern history, the role of the First President, and its diverse exhibitions set it apart from other cultural institutions in Astana."
    },
    {
        "question": "What is the significance of the museum's collection of personal awards?",
        "answer": "The collection of personal awards highlights the international recognition and achievements of the head of state, contributing to the museum's historical narrative."
    },
    {
        "question": "How does the museum attract visitors?",
        "answer": "The museum attracts visitors through its authoritative status, diverse exhibitions, and educational programs."
    },
    {
        "question": "What types of exhibits can visitors expect to see at the museum?",
        "answer": "Visitors can expect to see a wide range of exhibits reflecting Kazakhstan's modern history, including personal awards of the head of state, thematic exhibitions, and items from various countries."
    },
    {
        "question": "What is the role of the museum in promoting patriotism?",
        "answer": "The museum promotes patriotism by educating visitors about Kazakhstan's modern history and the achievements of its First President."
    },
    {
        "question": "How does the museum contribute to historical research?",
        "answer": "The museum serves as a research center, providing scholars and visitors with access to its extensive collection and resources."
    },
    {
        "question": "What is the purpose of the museum's thematic exhibitions?",
        "answer": "Thematic exhibitions aim to explore specific topics related to Kazakhstan's modern history and the achievements of its First President."
    },
    {
        "question": "What is the significance of the museum's location in Nur-Sultan?",
        "answer": "The museum's location in Nur-Sultan, the capital of Kazakhstan, enhances its visibility and accessibility to visitors."
    },
    {
        "question": "How does the museum contribute to cultural enrichment?",
        "answer": "The museum contributes to cultural enrichment by showcasing diverse exhibits, fostering dialogue among visitors, and promoting cultural exchange."
    }
]

# %%
dataset_12 = [
    {
        "question": "What is the title of the landmark?",
        "answer": "Arc de Triomphe «Mәңgіlіk El»."
    },
    {
        "question": "Where is the landmark located?",
        "answer": "Астана, пр. Мәңgіlіk Ел."
    },
    {
        "question": "What is the phone number of the landmark?",
        "answer": "+7 (7172) 79-04-39"
    },
    {
        "question": "What are the working hours of the landmark?",
        "answer": "Mn-Fr: с 10:00 до 18:00, St-Sn: closed"
    },
    {
        "question": "What is the link to the landmark's website?",
        "answer": "https://astana.citypass.kz/en/2018/01/19/triumfalnaya-arka-m-gilik-el-2/"
    },
    {
        "question": "What is the height of the landmark?",
        "answer": "The height of the structure is equal to 20 meters, symbolizing the 20th anniversary of independence of Kazakhstan."
    },
    {
        "question": "What sculptures are located on the pedestals?",
        "answer": "On the pedestals, there are relief sculptures reflecting the mentality of the Kazakh nation, including a sculpture of an Aksakal and a Woman-Mother."
    },
    {
        "question": "What does the inscription 'Mangilik El' on the arch signify?",
        "answer": "The inscription 'Mangilik El' has a greater semantic meaning, symbolizing the eternal prosperity of Kazakhstan."
    },
    {
        "question": "What can visitors find inside the arch during the ascent?",
        "answer": "During the ascent, visitors can find landscape, reportage, and genre photos that tell the history of the city."
    },
    {
        "question": "When did the arc de Triomphe open to the General public?",
        "answer": "The arc de Triomphe opened to the General public on May 11, 2017."
    },
    {
        "question": "What sculptures are present on the observation platform?",
        "answer": "On the observation platform, visitors see the majestic figures of soldiers-sculptures: 'Batyr, guarding the day' and 'Batyr, guarding the night' (author Mansurov M. A.)."
    },
    {
        "question": "What exhibitions are displayed on the staircases?",
        "answer": "Permanent photo exhibitions are displayed on the staircases, including 'The History of the city of Akmolinsk-Tselinograd-Akmola-Astana' and 'Modern Astana'."
    },
    {
        "question": "What materials are available on the touch-screen information kiosks?",
        "answer": "The touch-screen information kiosks provide materials on 'Multimedia capital', 'Triumphal arches of the world', 'History of the city', 'Modern Astana', and 'Historical and cultural heritage of Astana'."
    },
    {
        "question": "What is the significance of visiting the Arc de Triomphe?",
        "answer": "Visitors will touch not only the culture but also the modern history of Kazakhstan, embedded in the idea of the arc de Triomphe."
    },
    {
        "question": "What history is embedded in the idea of the arc de Triomphe?",
        "answer": "The entire history of the Republic of Kazakhstan and the heritage of the Kazakh people are embedded in the idea of the arc de Triomphe."
    },
    {
        "question": "What role does the landmark play in the city?",
        "answer": "The landmark serves as a place that every resident and guest of the capital must visit, offering insights into the culture and history of Kazakhstan."
    },
    {
        "question": "What is the significance of the sculptures on the arch?",
        "answer": "The sculptures reflect the mentality of the Kazakh nation and symbolize wisdom, spirituality, and the role of women in society."
    },
    {
        "question": "How does the landmark commemorate Kazakhstan's independence?",
        "answer": "The height of the structure symbolizes the 20th anniversary of independence, and the inscription 'Mangilik El' signifies eternal prosperity."
    },
    {
        "question": "What information is provided on the touch-screen kiosk about 'Modern Astana'?",
        "answer": "The touch-screen kiosk provides information about the modern development and features of the city of Astana."
    },
    {
        "question": "What types of photos are displayed inside the arch?",
        "answer": "Inside the arch, visitors can find landscape, reportage, and genre photos that depict the history of the city."
    },
    {
        "question": "What does the sculpture of an Aksakal symbolize?",
        "answer": "The sculpture symbolizes wisdom and the carrier of spirituality and thought of the Kazakh people."
    },
    {
        "question": "What is the artistic significance of the soldiers-sculptures?",
        "answer": "The soldiers-sculptures represent the strength and solemnity of Kazakhstan's history and heritage."
    },
    {
        "question": "What does the inscription 'Mangilik El' mean?",
        "answer": "The inscription signifies eternal prosperity and greatness for Kazakhstan."
    },
    {
        "question": "What exhibitions are available on the observation platform?",
        "answer": "Permanent photo exhibitions depicting the history and modern development of Astana are available on the observation platform."
    },
    {
        "question": "How does the landmark contribute to cultural awareness?",
        "answer": "The landmark provides insights into the culture and history of Kazakhstan, fostering cultural awareness among visitors."
    },
    {
        "question": "What is the purpose of the permanent photo exhibitions?",
        "answer": "The purpose is to showcase the historical and modern development of Astana, providing visitors with a comprehensive understanding of the city's evolution."
    },
    {
        "question": "What is the role of the arc de Triomphe in preserving Kazakhstan's heritage?",
        "answer": "The arc de Triomphe preserves and showcases the history and heritage of Kazakhstan, ensuring that it is accessible to residents and visitors alike."
    },
    {
        "question": "How does the landmark engage with visitors?",
        "answer": "The landmark engages visitors through exhibitions, sculptures, and informative materials, offering them a holistic experience of Kazakhstan's culture and history."
    },
    {
        "question": "What themes do the relief sculptures on the pedestals represent?",
        "answer": "The relief sculptures represent the mentality of the Kazakh nation, depicting themes of wisdom and the role of women in society."
    },
    {
        "question": "What significance does the inscription 'Mangilik El' hold?",
        "answer": "The inscription symbolizes the eternal prosperity and greatness of Kazakhstan, encapsulating the aspirations of the Kazakh people."
    },
    {
        "question": "How does the landmark contribute to education?",
        "answer": "The landmark educates visitors about the history and culture of Kazakhstan through exhibitions, sculptures, and informative materials."
    },
    {
        "question": "What emotions does the landmark evoke in visitors?",
        "answer": "The landmark evokes a sense of pride, awe, and appreciation for Kazakhstan's history and heritage."
    },
    {
        "question": "What is the significance of the sculptures 'Batyr, guarding the day' and 'Batyr, guarding the night'?",
        "answer": "The sculptures symbolize the strength and vigilance of Kazakhstan, guarding its prosperity both day and night."
    },
    {
        "question": "How does the landmark contribute to the identity of Astana?",
        "answer": "The landmark serves as an iconic symbol of Astana, representing its modern development and historical significance."
    },
    {
        "question": "What is the main theme of the arc de Triomphe?",
        "answer": "The main theme is to commemorate Kazakhstan's independence and showcase its history and heritage."
    },
    {
        "question": "How does the landmark enhance the visitor experience?",
        "answer": "The landmark enhances the visitor experience through informative materials, exhibitions, and interactive elements, providing a deeper understanding of Kazakhstan's culture and history."
    },
    {
        "question": "What historical events does the landmark commemorate?",
        "answer": "The landmark commemorates Kazakhstan's independence and celebrates its achievements and heritage."
    },
    {
        "question": "What is the architectural significance of the arc de Triomphe?",
        "answer": "The architectural design of the arc de Triomphe reflects the modernity and aspirations of Kazakhstan, symbolizing its progress and prosperity."
    }
]

# %%
dataset_11 = [
    {
        "question": "What is the title of the building?",
        "answer": "Palace of Independence."
    },
    {
        "question": "Where is the building located?",
        "answer": "Астана, проспект Тауелсыздык, 52."
    },
    {
        "question": "What is the phone number of the building?",
        "answer": "+7 (7172) 79-04-39"
    },
    {
        "question": "What are the working hours of the building?",
        "answer": "Пн: технический день, Вт-Вс: с 10:00 до 18:00"
    },
    {
        "question": "What is the link to the building's website?",
        "answer": "https://astana.citypass.kz/en/2018/04/28/dvorets-nezavisimosti/"
    },
    {
        "question": "How would you describe the architectural style of the Palace of Independence?",
        "answer": "The Palace of Independence features a modern futuristic design, resembling a trapezoid made of glass and decorated with a zigzag snow-white lattice."
    },
    {
        "question": "When did the construction of the Palace of Independence begin and end?",
        "answer": "The construction began in 2007 and was completed by the end of 2008."
    },
    {
        "question": "Who was the author of the architectural project?",
        "answer": "The author of the project was a Turkish architect."
    },
    {
        "question": "What was the purpose behind constructing the Palace of Independence?",
        "answer": "The Palace of Independence was conceived as a venue for meetings, forums, conferences, and international events, as well as domestic gatherings."
    },
    {
        "question": "What is housed on the first floor of the Palace?",
        "answer": "The first floor houses the Congress hall, a hall for ceremonies, a press center, and a Banquet hall."
    },
    {
        "question": "How many people can the Congress hall accommodate?",
        "answer": "The Congress hall can accommodate more than 3,000 people."
    },
    {
        "question": "What important events are held in the hall for ceremonies?",
        "answer": "Important events such as the inauguration of the President are held in the hall for ceremonies."
    },
    {
        "question": "What is located on the second floor of the Palace?",
        "answer": "The second floor of the Palace is dedicated to art, featuring galleries and exhibition halls with both permanent and temporary exhibitions."
    },
    {
        "question": "What unique exhibits can be found in the hall of archeology?",
        "answer": "The hall of archeology houses exhibits such as a Sarmatian warrior and the 'Golden man' - the remains of a Saka warrior from the 5th century BC adorned with pure gold clothing."
    },
    {
        "question": "What is housed on the third floor of the Palace?",
        "answer": "The third floor houses the Museum of the history of the capital of Kazakhstan."
    },
    {
        "question": "What additional facilities does the Palace have?",
        "answer": "The Palace has a gallery of modern art, an electronic library, and facilities to explore the history of Astana and Kazakhstan."
    },
    {
        "question": "What can visitors expect to find in the electronic library?",
        "answer": "Visitors can explore the history of Astana and Kazakhstan, view archaeological finds, and access modern documents related to the formation of the Republic and the construction of its capital."
    },
    {
        "question": "What is the purpose of the Museum of the history of the capital of Kazakhstan?",
        "answer": "The museum aims to showcase the history and development of the capital city of Kazakhstan."
    },
    {
        "question": "What is the significance of the Palace of Independence?",
        "answer": "The Palace of Independence serves as a key venue for various events and exhibitions, reflecting the dynamic development of Kazakhstan and its capital."
    },
    {
        "question": "How does the Palace contribute to cultural enrichment?",
        "answer": "The Palace houses galleries, exhibitions, and museums dedicated to art, history, and archaeology, enriching visitors with cultural insights."
    },
    {
        "question": "What is the primary function of the Congress hall?",
        "answer": "The Congress hall serves as a venue for large gatherings, conferences, and international events."
    },
    {
        "question": "What is the capacity of the Banquet hall?",
        "answer": "The Banquet hall can accommodate about 700 people for a festive feast."
    },
    {
        "question": "What is the significance of the sculptures on the Palace?",
        "answer": "The sculptures reflect the aspirations and heritage of Kazakhstan, showcasing its cultural and historical richness."
    },
    {
        "question": "What makes the Palace of Independence unique?",
        "answer": "The Palace's modern futuristic design, versatile facilities, and focus on art and history make it a unique landmark in Astana."
    },
    {
        "question": "How does the Palace of Independence reflect the independence of Kazakhstan?",
        "answer": "The Palace's design and purpose symbolize the independence and dynamic development of Kazakhstan, serving as a testament to its progress."
    },
    {
        "question": "What types of events are typically held in the Congress hall?",
        "answer": "The Congress hall hosts a variety of events, including meetings, forums, conferences, and international gatherings."
    },
    {
        "question": "What role does the Palace play in promoting cultural heritage?",
        "answer": "The Palace preserves and showcases Kazakhstan's cultural heritage through its galleries, museums, and exhibitions, fostering cultural awareness and appreciation."
    },
    {
        "question": "How does the Palace contribute to international relations?",
        "answer": "The Palace serves as a venue for international events, conferences, and forums, promoting dialogue and cooperation between Kazakhstan and other nations."
    },
    {
        "question": "What distinguishes the Palace of Independence from other buildings in Astana?",
        "answer": "The Palace's unique design, versatile facilities, and focus on art and history distinguish it from other buildings in Astana."
    },
    {
        "question": "What is the role of the electronic library in the Palace?",
        "answer": "The electronic library provides visitors with access to historical documents, archaeological findings, and modern resources related to Kazakhstan's history and development."
    },
    {
        "question": "How does the Palace contribute to public education?",
        "answer": "The Palace educates the public about Kazakhstan's history and culture through its exhibitions, museums, and educational programs."
    },
    {
        "question": "What is the significance of the Palace of Independence for Kazakhstan?",
        "answer": "The Palace symbolizes Kazakhstan's independence, progress, and cultural richness, serving as a landmark for its capital city."
    },
    {
        "question": "What is the primary function of the Museum of the history of the capital of Kazakhstan?",
        "answer": "The museum aims to educate visitors about the history and development of Astana, the capital city of Kazakhstan."
    },
    {
        "question": "How does the Palace of Independence contribute to tourism in Astana?",
        "answer": "The Palace attracts tourists by offering insights into Kazakhstan's history and culture through its exhibitions, museums, and architectural design."
    },
    {
        "question": "What is the significance of the Palace's location in Astana?",
        "answer": "The Palace's location in Astana enhances its accessibility and visibility, making it a prominent landmark in the city."
    },
    {
        "question": "What is the capacity of the press center?",
        "answer": "The press center is equipped to accommodate media activities and events."
    },
    {
        "question": "What is the historical significance of the archaeological exhibits?",
        "answer": "The archaeological exhibits provide insights into Kazakhstan's ancient history, showcasing artifacts such as the 'Golden man' from the 5th century BC."
    },
    {
        "question": "What is the main theme of the Palace's exhibitions?",
        "answer": "The exhibitions at the Palace focus on Kazakhstan's history, culture, and development, providing visitors with a comprehensive understanding of the country."
    },
    {
        "question": "What role does the Palace play in hosting official ceremonies?",
        "answer": "The Palace serves as a venue for official ceremonies, including the inauguration of the President and other significant events."
    },
    {
        "question": "How does the Palace contribute to the cultural identity of Kazakhstan?",
        "answer": "The Palace showcases Kazakhstan's cultural heritage and artistic achievements, contributing to the country's cultural identity and pride."
    }
]

# %%
dataset_10 = [
    {
        "question": "What is the title of the exhibition?",
        "answer": "The Hall of Gold in the National Museum of the Republic of Kazakhstan."
    },
    {
        "question": "Where is the exhibition located?",
        "answer": "Астана, проспект Тәуелсіздік, 54."
    },
    {
        "question": "What is the phone number of the exhibition?",
        "answer": "+7 (7172) 79-04-39"
    },
    {
        "question": "What is the link to the exhibition's webpage?",
        "answer": "https://astana.citypass.kz/en/2018/09/05/zal-zoloto-v-nacionalynom-muzee-respubliki-kazahstan/"
    },
    {
        "question": "What is the purpose of the Hall of Gold?",
        "answer": "The Hall of Gold serves as a treasury and storage of unique valuable artifacts, particularly those made of gold and precious metals found in Kazakhstan."
    },
    {
        "question": "How often is the exposition of the hall updated?",
        "answer": "The exposition of the hall is annually updated with unique exhibits made of gold and precious metals found within the framework of the state program 'Cultural heritage'."
    },
    {
        "question": "What is significant about the gold products of the Scythian-Saka culture?",
        "answer": "Gold products of the Scythian-Saka culture are known worldwide for their richness and uniqueness, especially those found in rich burials of Saka leaders."
    },
    {
        "question": "What is the hallmark of the Scythian-Saka culture?",
        "answer": "The hallmark of the Scythian-Saka culture is the so-called 'animal style'."
    },
    {
        "question": "What time period do the gold products in the exhibition cover?",
        "answer": "The exhibition presents gold products covering the time period from the Bronze Age to the Golden Horde."
    },
    {
        "question": "What are the main components of the 'Scythian triad'?",
        "answer": "The 'Scythian triad' consists of standard samples of weapons, horse harnesses, and art objects found in the famous Saka burial grounds."
    },
    {
        "question": "What is the significance of the gold earring from the Mayemer burial ground?",
        "answer": "The gold earring from the Mayemer burial ground is a rarity and represents a significant archaeological find from East Kazakhstan."
    },
    {
        "question": "What is the main exhibit of the exhibition?",
        "answer": "The main exhibit of the exhibition is the 'Golden man', a prominent example of Saka art found during the excavation of the Issyk mound."
    },
    {
        "question": "Who led the excavation that discovered the 'Golden man'?",
        "answer": "The 'Golden man' was found during the excavation of the Issyk mound by a group of archaeologists under the leadership of Kemal Akishev."
    },
    {
        "question": "What is notable about the 'Golden man'?",
        "answer": "The 'Golden man' includes more than 4 thousand gold products made in a variety of techniques, representing the pinnacle of Saka art in the 'animal style'."
    },
    {
        "question": "What is the historical significance of the 'Golden man'?",
        "answer": "The 'Golden man' is a significant historical artifact dating back to the V-IV centuries BC, providing insights into the culture and craftsmanship of the Saka people."
    },
    {
        "question": "How many gold ornaments are included in the clothing elements of the 'Golden man'?",
        "answer": "The clothing elements of the 'Golden man' include more than 1800 gold ornaments in the form of fish scales."
    },
    {
        "question": "What techniques were used to create the gold products of the 'Golden man'?",
        "answer": "The gold products of the 'Golden man' were made using techniques such as forging, stamping, engraving, and grain."
    },
    {
        "question": "What regions of Kazakhstan are represented in the exhibits?",
        "answer": "Exhibits from regions such as East Kazakhstan and Karaganda region are represented in the exhibition."
    },
    {
        "question": "What is the aesthetic approach of the early nomads of the Saka time?",
        "answer": "The aesthetic approach of the early nomads of the Saka time is reflected in their rich burial artifacts and the 'Scythian triad' found in burial grounds."
    },
    {
        "question": "How does the Hall of Gold contribute to preserving Kazakhstan's cultural heritage?",
        "answer": "The Hall of Gold preserves and showcases valuable artifacts from Kazakhstan's history, particularly those related to the Scythian-Saka culture, contributing to the preservation of the country's cultural heritage."
    },
    {
        "question": "What makes the Hall of Gold unique among other exhibitions?",
        "answer": "The Hall of Gold stands out for its collection of unique gold artifacts, particularly those from the Scythian-Saka culture, providing visitors with a glimpse into Kazakhstan's rich history."
    },
    {
        "question": "What is the cultural significance of the 'Scythian triad'?",
        "answer": "The 'Scythian triad' represents the cultural and artistic achievements of the early nomads of the Saka time, showcasing their mastery in weaponry, horse harnesses, and art."
    },
    {
        "question": "How does the Hall of Gold contribute to archaeological research?",
        "answer": "The Hall of Gold provides valuable insights for archaeological research through its collection of artifacts, offering researchers a deeper understanding of Kazakhstan's ancient history."
    },
    {
        "question": "What themes are explored in the exhibition?",
        "answer": "The exhibition explores themes such as the Scythian-Saka culture, craftsmanship, aesthetics, and the historical significance of gold artifacts in Kazakhstan."
    },
    {
        "question": "What are some examples of gold artifacts found in the exhibition?",
        "answer": "Examples of gold artifacts include the gold earring from the Mayemer burial ground and the more than 1800 gold ornaments in the clothing elements of the 'Golden man'."
    },
    {
        "question": "How does the Hall of Gold contribute to public education?",
        "answer": "The Hall of Gold educates the public about Kazakhstan's rich history and cultural heritage through its exhibitions and displays of valuable artifacts."
    },
    {
        "question": "What is the significance of the Hall of Gold for Kazakhstan?",
        "answer": "The Hall of Gold symbolizes Kazakhstan's cultural richness and historical legacy, serving as a reminder of the country's ancient heritage and artistic achievements."
    },
    {
        "question": "What role does the Hall of Gold play in promoting tourism?",
        "answer": "The Hall of Gold attracts tourists by offering them a unique opportunity to explore Kazakhstan's history and cultural treasures, particularly its gold artifacts."
    },
    {
        "question": "How does the Hall of Gold contribute to national pride?",
        "answer": "The Hall of Gold instills a sense of national pride by showcasing Kazakhstan's cultural achievements and heritage, fostering appreciation for the country's rich history."
    },
    {
        "question": "What are the main themes depicted in the exhibits?",
        "answer": "The main themes depicted in the exhibits include the Scythian-Saka culture, craftsmanship, ancient burial practices, and the historical significance of gold artifacts."
    },
    {
        "question": "What makes the 'Golden man' a significant historical find?",
        "answer": "The 'Golden man' is a significant historical find due to its exquisite craftsmanship, artistic value, and the insights it provides into the culture and society of the Saka people."
    },
    {
        "question": "What is the primary focus of the Hall of Gold's exhibitions?",
        "answer": "The primary focus of the Hall of Gold's exhibitions is to showcase Kazakhstan's rich history and cultural heritage through its collection of gold artifacts."
    },
    {
        "question": "How does the Hall of Gold contribute to cultural exchange?",
        "answer": "The Hall of Gold facilitates cultural exchange by showcasing Kazakhstan's cultural heritage to visitors from around the world, fostering a greater understanding and appreciation of the country's history."
    },
    {
        "question": "What is the cultural significance of the 'animal style' in Saka art?",
        "answer": "The 'animal style' in Saka art represents a unique cultural expression characterized by intricate animal motifs and symbolism, reflecting the spiritual and aesthetic beliefs of the Saka people."
    },
    {
        "question": "What materials are used in creating the gold artifacts?",
        "answer": "The gold artifacts are made primarily of gold and precious metals, showcasing the craftsmanship and artistic skills of ancient Kazakh artisans."
    },
    {
        "question": "What is the historical context of the 'Golden man'?",
        "answer": "The 'Golden man' dates back to the V-IV centuries BC, a period associated with the height of Saka culture and influence in Central Asia."
    }
]

# %%
dataset_9 = [
    {
        "question": "What is the title of the museum?",
        "answer": "Museum of Saken Seifullin."
    },
    {
        "question": "Where is the museum located?",
        "answer": "Астана, ул. Ауэзова, 20."
    },
    {
        "question": "What is the phone number of the museum?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the museum's webpage?",
        "answer": "https://astana.citypass.kz/en/2018/02/15/muzey-sakena-seyfullina/"
    },
    {
        "question": "When was the Seifullin Museum opened?",
        "answer": "The Seifullin Museum in Astana was opened in 1988."
    },
    {
        "question": "What is the historical significance of the museum building?",
        "answer": "The museum building, constructed in 1946, is considered an architectural monument of the last century."
    },
    {
        "question": "How many halls does the Seifullin Museum consist of?",
        "answer": "The Seifullin Museum consists of six halls."
    },
    {
        "question": "What is the focus of the museum's exhibits?",
        "answer": "The exhibits focus on various periods of Saken Seifullin's life, highlighting his role in cultural development and personal growth."
    },
    {
        "question": "How many exhibits characterize Saken Seifullin's life and activities?",
        "answer": "More than 5,000 exhibits characterize Saken Seifullin's life and social activities."
    },
    {
        "question": "What type of items can visitors see in the museum's collection?",
        "answer": "Visitors can see personal belongings, books, photos, manuscripts, and other items related to Saken Seifullin's life and era."
    },
    {
        "question": "Who is Nina Mokina in relation to Saken Seifullin?",
        "answer": "Nina Mokina was the poet's muse, and photos of her are included among the museum's exhibits."
    },
    {
        "question": "What services does the museum provide for tourist groups?",
        "answer": "The museum provides excursion support for tourist groups for a more detailed acquaintance with Saken Seifullin's work."
    },
    {
        "question": "What educational activities does the museum offer?",
        "answer": "The museum regularly hosts open classes and seminars for schoolchildren and students."
    },
    {
        "question": "What period of time does the museum cover in its exhibits?",
        "answer": "The museum covers the fruitful life of Saken Seifullin in Akmolinskaya during the 20-30 years of the 20th century."
    },
    {
        "question": "What is the significance of Saken Seifullin in Kazakh culture?",
        "answer": "Saken Seifullin is significant in Kazakh culture for his contributions to literature and cultural development."
    },
    {
        "question": "How does the museum preserve the memory of Saken Seifullin?",
        "answer": "The museum preserves the memory of Saken Seifullin through its exhibits and educational programs, ensuring his legacy is remembered."
    },
    {
        "question": "What is the importance of Saken Seifullin's personal belongings in the museum's collection?",
        "answer": "Saken Seifullin's personal belongings offer insights into his life, personality, and the historical context in which he lived."
    },
    {
        "question": "Why are open classes and seminars held at the museum?",
        "answer": "Open classes and seminars are held to educate visitors, particularly schoolchildren and students, about Saken Seifullin's work and cultural significance."
    },
    {
        "question": "How does the museum make visitors feel closer to Saken Seifullin?",
        "answer": "The museum allows visitors to see personal items and photos of Saken Seifullin, fostering a sense of closeness to the poet and his era."
    },
    {
        "question": "What is the role of the museum in cultural education?",
        "answer": "The museum plays a vital role in cultural education by preserving and presenting the life and work of Saken Seifullin to the public."
    },
    {
        "question": "How does the museum contribute to promoting Saken Seifullin's legacy?",
        "answer": "The museum promotes Saken Seifullin's legacy through its exhibits, educational activities, and outreach efforts."
    },
    {
        "question": "What can visitors learn about Saken Seifullin from the museum's collection?",
        "answer": "Visitors can learn about Saken Seifullin's life, contributions to literature, and his impact on Kazakh culture from the museum's collection."
    },
    {
        "question": "What distinguishes the Seifullin Museum from other museums in Astana?",
        "answer": "The Seifullin Museum stands out for its focus on the life and works of Saken Seifullin, offering visitors a unique perspective on the poet and his era."
    },
    {
        "question": "How does the museum contribute to cultural tourism in Astana?",
        "answer": "The museum attracts cultural tourists interested in learning about Saken Seifullin and exploring Kazakhstan's literary heritage."
    },
    {
        "question": "What can visitors expect to see in the museum's six halls?",
        "answer": "Visitors can expect to see exhibits covering various aspects of Saken Seifullin's life, including personal belongings, photos, manuscripts, and historical context."
    },
    {
        "question": "What is the significance of the museum's location in Astana?",
        "answer": "The museum's location in Astana makes it accessible to visitors and contributes to the city's cultural landscape."
    },
    {
        "question": "What makes Saken Seifullin a notable figure in Kazakh literature?",
        "answer": "Saken Seifullin is notable for his contributions to Kazakh literature, particularly for his poetry and cultural activism."
    },
    {
        "question": "How does the museum honor Saken Seifullin's memory?",
        "answer": "The museum honors Saken Seifullin's memory by preserving his personal belongings and showcasing his achievements to the public."
    },
    {
        "question": "What is the main focus of the museum's educational programs?",
        "answer": "The main focus of the museum's educational programs is to promote awareness and appreciation of Saken Seifullin's life and works among visitors."
    },
    {
        "question": "How does the museum contribute to cultural enrichment in Astana?",
        "answer": "The museum enriches Astana's cultural scene by offering insights into the life and works of Saken Seifullin, a prominent figure in Kazakh literature."
    },
    {
        "question": "What role does Saken Seifullin play in the cultural heritage of Kazakhstan?",
        "answer": "Saken Seifullin is an integral part of Kazakhstan's cultural heritage, representing the country's literary legacy and cultural identity."
    },
    {
        "question": "What distinguishes the museum's collection of Saken Seifullin's artifacts?",
        "answer": "The museum's collection of Saken Seifullin's artifacts offers a comprehensive overview of the poet's life, from personal items to historical context."
    },
    {
        "question": "How does the museum engage with visitors?",
        "answer": "The museum engages with visitors through its exhibits, guided tours, open classes, and seminars, providing opportunities for learning and reflection."
    },
    {
        "question": "What is the significance of the museum's role in preserving cultural heritage?",
        "answer": "The museum plays a vital role in preserving Saken Seifullin's cultural heritage and ensuring that future generations can appreciate his contributions to Kazakh literature."
    },
    {
        "question": "What is the primary goal of the museum's exhibitions?",
        "answer": "The primary goal of the museum's exhibitions is to celebrate the life and works of Saken Seifullin and promote awareness of his cultural legacy."
    },
    {
        "question": "How does the museum contribute to the promotion of Kazakh literature?",
        "answer": "The museum contributes to the promotion of Kazakh literature by highlighting the achievements of Saken Seifullin and showcasing the richness of the country's literary tradition."
    },
    {
        "question": "What makes Saken Seifullin's life and work relevant to contemporary audiences?",
        "answer": "Saken Seifullin's life and work remain relevant to contemporary audiences due to their exploration of universal themes such as identity, cultural heritage, and social activism."
    },
    {
        "question": "What is the significance of Saken Seifullin's contributions to culture and society?",
        "answer": "Saken Seifullin's contributions to culture and society are significant as they reflect the aspirations and struggles of the Kazakh people, promoting unity and national identity."
    }
]

# %%
dataset_8 = [
    {
        "question": "What is the title of the exotarium?",
        "answer": "Exotarium “Ailand”."
    },
    {
        "question": "Where is the exotarium located?",
        "answer": "Астана, Коргалжинское шоссе, 2."
    },
    {
        "question": "What is the phone number of the exotarium?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the exotarium's webpage?",
        "answer": "https://astana.citypass.kz/en/2022/01/17/ekzotarium-ailand/"
    },
    {
        "question": "What is the main focus of the description?",
        "answer": "The description is focused on the Orthodox community in Kazakhstan and the Uspensky (Assumption) Cathedral."
    },
    {
        "question": "When was the Uspensky (Assumption) Cathedral built?",
        "answer": "The Uspensky (Assumption) Cathedral was raised in 2009."
    },
    {
        "question": "What unique items does the cathedral preserve?",
        "answer": "The cathedral preserves relics of St. Andrew the Apostle, relics of saints from Kyiv Pechersk Lavra, an icon with relics of St. Andrew Svirsky, an icon of St. Mary of Egypt, and an icon of Our Lady of Kazan."
    },
    {
        "question": "Who decorated the interior of the church?",
        "answer": "The interior of the church was decorated by artists from the Russian village of Palekh."
    },
    {
        "question": "What role does the Uspensky Cathedral play in the Orthodox community?",
        "answer": "The Uspensky Cathedral acts as a center for the Orthodox community in Kazakhstan."
    },
    {
        "question": "What organizations are hosted by the cathedral?",
        "answer": "The cathedral hosts the Synod of Orthodox Churches of Kazakhstan and the Ss. Cyril and Methodius Spiritual and Cultural Center."
    },
    {
        "question": "What is the significance of the Uspensky Cathedral in Kazakhstan?",
        "answer": "The Uspensky Cathedral is significant as a religious and cultural landmark for the Orthodox community in Kazakhstan."
    },
    {
        "question": "How does the cathedral contribute to religious diversity in Kazakhstan?",
        "answer": "The cathedral represents the Orthodox Christian faith, adding to the religious diversity in Kazakhstan alongside mosques and other religious institutions."
    },
    {
        "question": "What makes the Uspensky Cathedral unique?",
        "answer": "The cathedral is unique due to its architectural design, cultural significance, and the presence of valuable relics and icons."
    },
    {
        "question": "What events or activities are held at the Uspensky Cathedral?",
        "answer": "The cathedral hosts religious services, ceremonies, and cultural events for the Orthodox community."
    },
    {
        "question": "How does the cathedral contribute to spiritual and cultural life in Kazakhstan?",
        "answer": "The cathedral serves as a center for spiritual and cultural activities, fostering a sense of community among Orthodox believers."
    },
    {
        "question": "What is the role of the Synod of Orthodox Churches of Kazakhstan?",
        "answer": "The Synod of Orthodox Churches of Kazakhstan plays a central role in governing and coordinating Orthodox religious affairs in the country."
    },
    {
        "question": "What is the historical background of the Uspensky Cathedral?",
        "answer": "The Uspensky Cathedral was built relatively recently in 2009 but holds significant religious and cultural importance for Orthodox Christians in Kazakhstan."
    },
    {
        "question": "How does the cathedral contribute to interfaith dialogue?",
        "answer": "The cathedral provides a space for interfaith dialogue and cooperation by hosting events and activities that promote understanding and tolerance among different religious communities."
    },
    {
        "question": "What is the cultural significance of the icons preserved in the cathedral?",
        "answer": "The icons preserved in the cathedral hold cultural and religious significance for Orthodox Christians, representing spiritual connections and historical traditions."
    },
    {
        "question": "How does the cathedral promote religious tolerance?",
        "answer": "The cathedral promotes religious tolerance by welcoming visitors of all faiths and fostering dialogue and understanding among religious communities."
    },
    {
        "question": "What is the architectural style of the Uspensky Cathedral?",
        "answer": "The architectural style of the Uspensky Cathedral reflects traditional Orthodox design elements and incorporates cultural motifs from the Russian village of Palekh."
    },
    {
        "question": "How does the cathedral contribute to the cultural identity of Kazakhstan?",
        "answer": "The cathedral contributes to the cultural identity of Kazakhstan by preserving Orthodox religious traditions and serving as a symbol of religious diversity in the country."
    },
    {
        "question": "What role does the Ss. Cyril and Methodius Spiritual and Cultural Center play?",
        "answer": "The Ss. Cyril and Methodius Spiritual and Cultural Center provides educational and cultural programs to promote Orthodox Christian values and traditions."
    },
    {
        "question": "What is the significance of the relics housed in the cathedral?",
        "answer": "The relics housed in the cathedral are revered by Orthodox Christians and serve as objects of veneration and spiritual devotion."
    },
    {
        "question": "How does the cathedral contribute to the cultural heritage of Kazakhstan?",
        "answer": "The cathedral contributes to the cultural heritage of Kazakhstan by preserving Orthodox religious practices and artifacts."
    },
    {
        "question": "What cultural influences are reflected in the decoration of the church interior?",
        "answer": "The decoration of the church interior reflects cultural influences from the Russian village of Palekh, known for its traditional painting style."
    },
    {
        "question": "What is the role of the Uspensky Cathedral in promoting religious unity?",
        "answer": "The Uspensky Cathedral promotes religious unity by providing a space for Orthodox Christians to come together in worship and fellowship."
    },
    {
        "question": "How does the cathedral contribute to the spiritual life of believers?",
        "answer": "The cathedral contributes to the spiritual life of believers by offering religious services, sacraments, and opportunities for prayer and contemplation."
    },
    {
        "question": "What measures does the cathedral take to preserve its historical and cultural significance?",
        "answer": "The cathedral takes measures to preserve its historical and cultural significance through conservation efforts, educational programs, and public outreach."
    },
    {
        "question": "What is the significance of the relics of St. Andrew the Apostle?",
        "answer": "The relics of St. Andrew the Apostle are considered sacred by Orthodox Christians and are believed to have spiritual power and significance."
    },
    {
        "question": "How does the cathedral contribute to the cultural exchange between Kazakhstan and other countries?",
        "answer": "The cathedral promotes cultural exchange by hosting international events, exhibitions, and collaborations with Orthodox communities from other countries."
    },
    {
        "question": "What cultural events are organized by the cathedral?",
        "answer": "The cathedral organizes cultural events such as concerts, art exhibitions, and religious festivals to celebrate Orthodox traditions and promote cultural exchange."
    },
    {
        "question": "How does the cathedral support the local community?",
        "answer": "The cathedral supports the local community by providing spiritual guidance, social services, and opportunities for cultural enrichment."
    },
    {
        "question": "What educational programs are offered by the Ss. Cyril and Methodius Spiritual and Cultural Center?",
        "answer": "The Ss. Cyril and Methodius Spiritual and Cultural Center offers educational programs on Orthodox Christian theology, history, and cultural traditions."
    },
    {
        "question": "What is the role of the cathedral in preserving religious heritage?",
        "answer": "The cathedral plays a vital role in preserving Orthodox religious heritage by safeguarding relics, icons, and sacred traditions passed down through generations."
    },
    {
        "question": "How does the cathedral contribute to the promotion of peace and harmony?",
        "answer": "The cathedral contributes to the promotion of peace and harmony by fostering interfaith dialogue, promoting understanding, and advocating for tolerance and cooperation."
    },
    {
        "question": "What impact does the Uspensky Cathedral have on the local community?",
        "answer": "The Uspensky Cathedral has a significant impact on the local community by providing spiritual support, cultural enrichment, and opportunities for community engagement."
    },
    {
        "question": "How does the cathedral commemorate religious holidays and events?",
        "answer": "The cathedral commemorates religious holidays and events through special services, ceremonies, and cultural programs that engage the community in spiritual celebrations."
    },
    {
        "question": "What role does the Uspensky Cathedral play in promoting cultural diversity?",
        "answer": "The Uspensky Cathedral promotes cultural diversity by welcoming visitors from diverse backgrounds and fostering appreciation for Orthodox Christian traditions and cultural heritage."
    },
    {
        "question": "What makes the Uspensky Cathedral a significant landmark in Kazakhstan?",
        "answer": "The Uspensky Cathedral is a significant landmark in Kazakhstan due to its architectural beauty, cultural importance, and role as a center of Orthodox Christian worship."
    },
    {
        "question": "How does the cathedral contribute to the spiritual well-being of its congregation?",
        "answer": "The cathedral contributes to the spiritual well-being of its congregation through religious services, sacraments, pastoral care, and opportunities for prayer and reflection."
    },
    {
        "question": "What historical events are associated with the Uspensky Cathedral?",
        "answer": "The Uspensky Cathedral was built in 2009 and has since become a symbol of Orthodox Christianity in Kazakhstan, hosting significant religious and cultural events."
    }
]

# %%
dataset_7 = [
    {
        "question": "What is the title of the Ferris wheel?",
        "answer": "The Ferris Wheel «Ailand»."
    },
    {
        "question": "Where is the Ferris wheel located?",
        "answer": "Астана, Коргалжинское шоссе, 2."
    },
    {
        "question": "What is the phone number of the Ferris wheel?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the Ferris wheel's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/koleso-obozreniya-duman/"
    },
    {
        "question": "What is the height and weight of the Ferris wheel?",
        "answer": "The Ferris wheel is 65 meters high and weighs 270 tons."
    },
    {
        "question": "What is special about the Ferris wheel's design?",
        "answer": "The Ferris wheel's design is specially developed to withstand the climatic features of Astana."
    },
    {
        "question": "How many enclosed booths does the Ferris wheel have?",
        "answer": "The Ferris wheel is equipped with 36 enclosed booths."
    },
    {
        "question": "What amenities are provided in each booth?",
        "answer": "Each booth is equipped with air conditioning and heating systems."
    },
    {
        "question": "What is the capacity of a standard cabin?",
        "answer": "The capacity of a standard cabin is 6 people."
    },
    {
        "question": "How many high-comfort cabins are there?",
        "answer": "There are four high-comfort cabins."
    },
    {
        "question": "When is the Ferris wheel open?",
        "answer": "The Ferris wheel is open all day."
    },
    {
        "question": "What is the significance of the Ferris wheel for Nur-Sultan (Astana)?",
        "answer": "The Ferris wheel became a new attraction of Nur-Sultan (Astana) and won the hearts of residents and guests of the city."
    },
    {
        "question": "Who was one of the first to ride the Ferris wheel?",
        "answer": "Anastasia Ivleeva, the host of the program \"heads and Tails. Reload\", was one of the first to ride the Ferris wheel."
    },
    {
        "question": "What views can you enjoy from the highest point of the Ferris wheel?",
        "answer": "From the highest point of the Ferris wheel, you can enjoy a beautiful view of the right and left bank of the city."
    },
    {
        "question": "What is emphasized about the city's architectural structures?",
        "answer": "The city's architectural structures are described as beautiful and bold solutions."
    },
    {
        "question": "How does the Ferris wheel operate in winter?",
        "answer": "In winter, the Ferris wheel operates at temperatures up to -15 degrees Celsius, with wind gusts of up to 20 meters per second."
    },
    {
        "question": "What is the ticket price for the Ferris wheel?",
        "answer": "Ticket prices for the Ferris wheel have become even more profitable."
    },
    {
        "question": "What benefit do Astana PASS holders have?",
        "answer": "Astana PASS holders can use the stairs located on the left, which are intended for exit."
    },
    {
        "question": "What experience can visitors expect from a ride on the Ferris wheel?",
        "answer": "Visitors can expect to enjoy excellent views of the capital from the height of bird flight and gain bright impressions."
    },
    {
        "question": "What role does the Ferris wheel play in showcasing the beauty of Astana?",
        "answer": "The Ferris wheel showcases the beauty of Astana from a new perspective, allowing visitors to fall in love with the city again."
    },
    {
        "question": "What makes the Ferris wheel unique compared to other attractions in Astana?",
        "answer": "The Ferris wheel offers panoramic views of the city and operates in various weather conditions, providing a unique experience for visitors."
    },
    {
        "question": "How does the Ferris wheel contribute to the tourism industry of Astana?",
        "answer": "The Ferris wheel attracts tourists and adds to the list of attractions in Astana, enhancing the city's tourism appeal."
    },
    {
        "question": "What promotional activity featured the Ferris wheel before its official opening?",
        "answer": "The Ferris wheel was featured in the famous TV show about travel \"heads and Tails. Reload\", with Anastasia Ivleeva being one of the first to ride it."
    },
    {
        "question": "What measures are taken to ensure visitor comfort on the Ferris wheel?",
        "answer": "The Ferris wheel is equipped with air conditioning and heating systems to ensure visitor comfort in any weather."
    },
    {
        "question": "What makes the Ferris wheel suitable for extreme weather conditions?",
        "answer": "The Ferris wheel's design incorporates technology used in tornado zones, making it suitable for extreme weather conditions."
    },
    {
        "question": "How does the Ferris wheel contribute to the entertainment options in Astana?",
        "answer": "The Ferris wheel offers a unique entertainment experience and adds to the diversity of attractions available in Astana."
    },
    {
        "question": "What distinguishes the Ferris wheel from other observation wheels?",
        "answer": "The Ferris wheel is the largest in Kazakhstan and offers enclosed booths with air conditioning and heating systems."
    },
    {
        "question": "What is the significance of the Ferris wheel's location?",
        "answer": "The Ferris wheel's location provides panoramic views of the city, showcasing its architectural beauty and landmarks."
    },
    {
        "question": "How does the Ferris wheel contribute to the city's skyline?",
        "answer": "The Ferris wheel adds to the city's skyline with its towering height and iconic presence."
    },
    {
        "question": "What role does the Ferris wheel play in promoting tourism?",
        "answer": "The Ferris wheel serves as a tourist attraction, offering visitors panoramic views of the city and enhancing their experience of Astana."
    },
    {
        "question": "What distinguishes the Ferris wheel's design from traditional Ferris wheels?",
        "answer": "The Ferris wheel's design is specially developed to withstand the climatic features of Astana and incorporates technology used in tornado zones."
    },
    {
        "question": "What amenities are provided in the high-comfort cabins?",
        "answer": "The high-comfort cabins offer additional amenities for a more luxurious experience."
    },
    {
        "question": "How does the Ferris wheel contribute to the city's tourism economy?",
        "answer": "The Ferris wheel attracts tourists, generating revenue for the city's tourism industry."
    },
    {
        "question": "What promotional opportunities are available for visitors to the Ferris wheel?",
        "answer": "Visitors can take advantage of promotional offers such as discounts and special packages for tickets."
    },
    {
        "question": "What distinguishes the Ferris wheel's construction process?",
        "answer": "The Ferris wheel's construction process incorporates technology used in tornado zones, ensuring its stability in extreme weather conditions."
    },
    {
        "question": "How does the Ferris wheel contribute to the city's reputation?",
        "answer": "The Ferris wheel enhances the city's reputation as a modern and tourist-friendly destination."
    },
    {
        "question": "What is the cultural significance of the Ferris wheel?",
        "answer": "The Ferris wheel adds to the cultural landscape of Astana, providing residents and visitors with a unique perspective of the city."
    },
    {
        "question": "How does the Ferris wheel contribute to the city's leisure activities?",
        "answer": "The Ferris wheel offers a leisure activity that allows visitors to relax and enjoy panoramic views of the city."
    },
    {
        "question": "What is the capacity of the Ferris wheel?",
        "answer": "The Ferris wheel can accommodate up to 6 people in a standard cabin."
    },
    {
        "question": "What safety measures are in place for visitors to the Ferris wheel?",
        "answer": "The Ferris wheel is designed and operated to meet safety standards, ensuring a secure experience for visitors."
    },
    {
        "question": "What makes the Ferris wheel a popular attraction?",
        "answer": "The Ferris wheel's panoramic views, comfortable cabins, and unique design make it a popular attraction for visitors."
    },
    {
        "question": "How does the Ferris wheel enhance the city's skyline?",
        "answer": "The Ferris wheel adds to the city's skyline with its towering height and iconic presence."
    }
]

# %%
dataset_6 = [
    {
        "question": "What is the title of the oceanarium?",
        "answer": "The Oceanarium «Ailand»."
    },
    {
        "question": "Where is the oceanarium located?",
        "answer": "Астана, Коргалжинское шоссе, 2."
    },
    {
        "question": "What is the phone number of the oceanarium?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the oceanarium's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/rts-duman/"
    },
    {
        "question": "What is unique about the oceanarium's location?",
        "answer": "The oceanarium is considered to be the most remote from the ocean in the world, with a distance of more than 3000 km from the nearest ocean."
    },
    {
        "question": "When did the oceanarium open?",
        "answer": "The oceanarium opened back in 2003."
    },
    {
        "question": "How much water does the oceanarium hold?",
        "answer": "The oceanarium holds 3 million liters of water and 120 tons of sea salt."
    },
    {
        "question": "How many tourists visit the oceanarium annually?",
        "answer": "Hundreds of thousands of tourists visit the oceanarium every year."
    },
    {
        "question": "What kind of marine animals can visitors see in the oceanarium?",
        "answer": "Visitors can see more than two thousand marine animals, including representatives of several hundred species."
    },
    {
        "question": "What are some examples of marine animals in the oceanarium?",
        "answer": "Examples of marine animals in the oceanarium include cat sharks, starfish, and seahorses."
    },
    {
        "question": "What is special about the central reservoir in the oceanarium?",
        "answer": "The central reservoir has an acrylic tunnel with a length of 70 meters, giving visitors the feeling of being on the sea floor."
    },
    {
        "question": "How many exhibition bays does the oceanarium have?",
        "answer": "The oceanarium has two exhibition bays."
    },
    {
        "question": "What can visitors observe in the exhibition bays?",
        "answer": "Visitors can observe the life of fish in tanks of various volumes and learn about the life of inhabitants of the deep ocean from different parts of the world."
    },
    {
        "question": "What types of fish are housed in the oceanarium?",
        "answer": "Residents of fresh waters of the South-Eastern region, inhabitants of coral reefs, and exotic inhabitants of South America are housed in the oceanarium."
    },
    {
        "question": "What is the experience like for visitors to the oceanarium?",
        "answer": "Visitors typically have a positive experience and enjoy a trip to the oceanarium, often leaving with positive emotions."
    },
    {
        "question": "How does the oceanarium enhance its visitors' experience?",
        "answer": "The oceanarium offers a ticket price discount with an Astana PASS smart card and allows visitors to bypass queues with an online card."
    },
    {
        "question": "What is the capacity of the oceanarium?",
        "answer": "The capacity of the oceanarium is not specified."
    },
    {
        "question": "What is the role of the oceanarium in promoting tourism?",
        "answer": "The oceanarium serves as a tourist attraction, drawing visitors to Astana."
    },
    {
        "question": "What is the significance of the oceanarium's Guinness World Records listing?",
        "answer": "The oceanarium's listing in the Guinness World Records adds to its uniqueness and appeal as a tourist destination."
    },
    {
        "question": "How does the oceanarium contribute to education about marine life?",
        "answer": "The oceanarium educates visitors about marine life by showcasing a wide variety of species and habitats."
    },
    {
        "question": "What amenities are provided for visitors at the oceanarium?",
        "answer": "The oceanarium provides amenities such as ticket discounts and online booking options."
    },
    {
        "question": "What distinguishes the oceanarium from other attractions in Astana?",
        "answer": "The oceanarium's uniqueness lies in its remote location from the ocean and its Guinness World Records listing."
    },
    {
        "question": "How does the oceanarium contribute to the city's cultural landscape?",
        "answer": "The oceanarium adds diversity to the city's cultural offerings by providing an immersive experience of the ocean."
    },
    {
        "question": "What is the primary draw for visitors to the oceanarium?",
        "answer": "The primary draw for visitors is the opportunity to experience the underwater world and see a wide variety of marine animals."
    },
    {
        "question": "What kind of ticket discounts are available for the oceanarium?",
        "answer": "Ticket discounts are available with an Astana PASS smart card."
    },
    {
        "question": "How does the oceanarium contribute to the city's economy?",
        "answer": "The oceanarium attracts tourists, which contributes to the city's economy through spending on accommodation, dining, and other activities."
    },
    {
        "question": "What promotional opportunities are available for visitors to the oceanarium?",
        "answer": "Visitors can take advantage of promotional offers such as ticket discounts and queue bypass with an online card."
    },
    {
        "question": "What makes the oceanarium's acrylic tunnel unique?",
        "answer": "The acrylic tunnel in the oceanarium is 70 meters long and gives visitors the feeling of being on the sea floor."
    },
    {
        "question": "How does the oceanarium accommodate visitors?",
        "answer": "The oceanarium accommodates visitors by providing an immersive experience of the underwater world and offering amenities such as ticket discounts."
    },
    {
        "question": "What is the primary attraction of the oceanarium?",
        "answer": "The primary attraction of the oceanarium is its extensive collection of marine animals and its Guinness World Records listing."
    },
    {
        "question": "What distinguishes the oceanarium's exhibitions?",
        "answer": "The oceanarium's exhibitions showcase a wide variety of marine life and habitats, allowing visitors to learn about different ecosystems."
    },
    {
        "question": "How does the oceanarium contribute to environmental awareness?",
        "answer": "The oceanarium educates visitors about marine conservation and the importance of protecting ocean ecosystems."
    },
    {
        "question": "What role does the oceanarium play in entertainment in Astana?",
        "answer": "The oceanarium offers entertainment by providing an immersive experience of the underwater world."
    },
    {
        "question": "What are the benefits of visiting the oceanarium?",
        "answer": "Visitors to the oceanarium can enjoy an immersive experience of marine life and learn about different species and habitats."
    },
    {
        "question": "How does the oceanarium accommodate large crowds?",
        "answer": "The oceanarium offers amenities such as online booking and ticket discounts to accommodate large crowds."
    },
    {
        "question": "What is the significance of the oceanarium's location?",
        "answer": "The oceanarium's remote location from the ocean adds to its uniqueness and appeal as a tourist destination."
    },
    {
        "question": "What distinguishes the oceanarium's design?",
        "answer": "The oceanarium's design incorporates large reservoirs that hold millions of liters of water and create natural conditions for marine inhabitants."
    },
    {
        "question": "How does the oceanarium contribute to scientific research?",
        "answer": "The oceanarium contributes to scientific research by providing a controlled environment for studying marine life and behavior."
    },
    {
        "question": "What educational opportunities are available at the oceanarium?",
        "answer": "The oceanarium offers educational programs for visitors to learn about marine life and conservation."
    },
    {
        "question": "What are some features of the oceanarium's exhibitions?",
        "answer": "The oceanarium's exhibitions feature a variety of tanks with different volumes and habitats, allowing visitors to observe marine life up close."
    },
    {
        "question": "How does the oceanarium enhance its visitors' experience?",
        "answer": "The oceanarium enhances its visitors' experience by offering amenities such as ticket discounts and online booking options."
    }
]

# %%
dataset_5 = [
    {
        "question": "What is the title of the monument?",
        "answer": "«Astana-Baiterek» Monument."
    },
    {
        "question": "Where is the monument located?",
        "answer": "Астана, Нуржол бульвар, 14."
    },
    {
        "question": "What is the phone number of the monument?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the monument's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/bayterek/"
    },
    {
        "question": "Who came up with the idea of erecting the monument?",
        "answer": "The idea of erecting the monument belongs to the First President of the Republic of Kazakhstan – Nursultan Nazarbayev."
    },
    {
        "question": "What inspired the idea of the monument?",
        "answer": "The idea of the monument arose from Nursultan Nazarbayev on Board the presidential plane, during a flight."
    },
    {
        "question": "What does the monument symbolize?",
        "answer": "The monument symbolizes the World river and the Tree of Life, interpreting the views of ancient nomads."
    },
    {
        "question": "What experience does the monument offer to visitors?",
        "answer": "Visitors can enjoy panoramic views of the capital and absorb the steppe expanse of Kazakhstan from the top of the monument."
    },
    {
        "question": "What is located at the center of the monument's hall?",
        "answer": "At the center of the hall is a wooden globe with autographs left by representatives of 17 religions."
    },
    {
        "question": "What tradition do visitors believe in when visiting the monument?",
        "answer": "Visitors believe that if they make a wish while putting their hand in the impression of the President's right hand, it will come true."
    },
    {
        "question": "Who supervised the construction of the monument?",
        "answer": "The construction of the monument was supervised by domestic architects B. Islamov and A. Rustembekov."
    },
    {
        "question": "How long did it take to construct the monument?",
        "answer": "The construction of the monument took 6 years, from 1996 to 2002."
    },
    {
        "question": "What award did the monument receive after its opening?",
        "answer": "After its opening, the monument was awarded the prestigious Grand Prix award in a competition organized by the international Association of the Union of Architects (MASA) of the CIS countries."
    },
    {
        "question": "How is the monument divided internally?",
        "answer": "Internally, the monument is divided into three zones: the underground level, the ground level, and the sky level."
    },
    {
        "question": "What facilities are available at the underground level of the monument?",
        "answer": "The underground level of the monument features aquariums, cafes, and an exhibition gallery with art objects."
    },
    {
        "question": "What is the ground level of the monument?",
        "answer": "The ground level of the monument is a tower with high-speed elevators."
    },
    {
        "question": "What is the sky level of the monument?",
        "answer": "The sky level of the monument is the glass ball itself, offering tourists panoramic views of the capital."
    },
    {
        "question": "What is the significance of the Baiterek monument?",
        "answer": "The Baiterek monument is the embodiment of the ideology of the entire state, representing the past, present, and future of Kazakhstan."
    },
    {
        "question": "What is the average annual number of tourists visiting the monument?",
        "answer": "On average, about 500 thousand tourists visit the monument every year."
    },
    {
        "question": "What major work was carried out on the monument in 2017?",
        "answer": "In 2017, major repairs and reconstruction of the monument were carried out, including finishing the interior."
    },
    {
        "question": "What was the price of a ticket to the monument after the restoration?",
        "answer": "After the restoration, the price of a ticket to the monument changed to 700 tenge for adults and 300 tenge for children."
    },
    {
        "question": "What amenities are available for visitors at the monument?",
        "answer": "For visitors, there are cozy cafes and bars, a shop with souvenirs, and polite staff ready to help."
    },
    {
        "question": "What is the role of the monument in promoting tourism?",
        "answer": "The monument is one of the main attractions of the capital that attracts tourists and contributes to the city's tourism industry."
    },
    {
        "question": "How does the monument accommodate large crowds of visitors?",
        "answer": "The monument offers amenities such as online booking to accommodate large crowds and reduce queues."
    },
    {
        "question": "What is the significance of the monument's design?",
        "answer": "The monument's design reflects the cultural and historical significance of Kazakhstan and its capital."
    },
    {
        "question": "What makes the monument a unique attraction?",
        "answer": "The monument's unique design and symbolism, along with its panoramic views, make it a must-visit attraction for tourists."
    },
    {
        "question": "How does the monument contribute to the city's cultural landscape?",
        "answer": "The monument adds to the city's cultural landscape by showcasing Kazakh culture and history through its architecture and exhibitions."
    },
    {
        "question": "What makes the monument a symbol of national pride?",
        "answer": "The monument's significance as a symbol of Kazakhstan's past, present, and future makes it a source of national pride for its citizens."
    },
    {
        "question": "What features of the monument's construction demonstrate its engineering prowess?",
        "answer": "The construction of the monument's tower and glass ball, along with its internal divisions and facilities, demonstrate its engineering complexity and innovation."
    },
    {
        "question": "What is the connection between the monument and ancient nomadic views?",
        "answer": "The monument's symbolism, such as the World river and the Tree of Life, interprets the views of ancient nomads, connecting the past with the present."
    },
    {
        "question": "What cultural significance does the monument hold for Kazakhstan?",
        "answer": "The monument holds cultural significance as a representation of Kazakhstan's identity, values, and aspirations for the future."
    },
    {
        "question": "How does the monument contribute to public engagement with history and culture?",
        "answer": "The monument offers exhibitions, galleries, and interactive experiences that engage visitors with Kazakh history, culture, and art."
    },
    {
        "question": "What is the philosophical meaning behind the monument's design?",
        "answer": "The monument's design symbolizes the connection between the past, present, and future, reflecting philosophical concepts of time and continuity."
    },
    {
        "question": "What cultural artifacts are displayed at the monument?",
        "answer": "The monument displays art objects and artifacts from Kazakh artists and cultural heritage sites."
    },
    {
        "question": "How does the monument contribute to religious diversity?",
        "answer": "The monument features a wooden globe with autographs from representatives of 17 religions, promoting religious diversity and tolerance."
    },
    {
        "question": "What role does the monument play in promoting tourism in Kazakhstan?",
        "answer": "The monument serves as a landmark attraction that draws tourists to Kazakhstan and showcases its cultural and architectural heritage."
    },
    {
        "question": "What amenities are available for visitors at the monument?",
        "answer": "The monument offers amenities such as cafes, bars, souvenir shops, and friendly staff to enhance visitors' experience."
    },
    {
        "question": "How does the monument contribute to the city's skyline?",
        "answer": "The monument's distinctive tower and glass ball add to the city's skyline, making it a recognizable feature of Astana's landscape."
    },
    {
        "question": "What role does the monument play in promoting national identity?",
        "answer": "The monument serves as a symbol of Kazakhstan's national identity, representing its history, culture, and aspirations for the future."
    },
    {
        "question": "What significance does the monument hold for visitors?",
        "answer": "For visitors, the monument offers a unique experience of Kazakhstan's culture, history, and architectural innovation."
    },
    {
        "question": "What is the historical context of the monument's construction?",
        "answer": "The monument was constructed in the late 20th and early 21st centuries as a symbol of Kazakhstan's independence and aspirations for the future."
    },
    {
        "question": "How does the monument reflect the aspirations of the Kazakh people?",
        "answer": "The monument reflects the Kazakh people's desire for progress, prosperity, and cultural preservation, as symbolized by its design and symbolism."
    }
]

# %%
dataset_4 = [
    {
        "question": "What is the title of the museum?",
        "answer": "National Museum of the Republic of Kazakhstan."
    },
    {
        "question": "Where is the museum located?",
        "answer": "Астана, пр. Тәуелсіздік, 54."
    },
    {
        "question": "What is the phone number of the museum?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the museum's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/05/15/natsionalnyiy-muzey-respubliki-kazahstan/"
    },
    {
        "question": "Who initiated the creation of the museum?",
        "answer": "The museum was created on behalf of the First President of Kazakhstan, Nursultan Nazarbayev."
    },
    {
        "question": "Where is the museum building located?",
        "answer": "The museum building is located on Independence Square, the main square of the country."
    },
    {
        "question": "What is the size of the museum's exhibition space?",
        "answer": "The museum has 11 exhibition halls with a total area of more than 14,000 sq. m."
    },
    {
        "question": "How many blocks does the museum complex consist of?",
        "answer": "The museum complex consists of seven blocks."
    },
    {
        "question": "What are the names of the main halls in the museum?",
        "answer": "The main halls include Astana Hall, Hall of Independent Kazakhstan, Halls of Gold, Hall of Ancient and Medieval History, Hall of History, Hall of Ethnography, and Halls of Modern Art."
    },
    {
        "question": "What facilities are available in the museum complex?",
        "answer": "The museum complex includes separate rooms for a children's museum, a center for children's creativity, exhibition halls, restoration workshops, laboratories, storage facilities, a scientific library, a conference room, and souvenir kiosks."
    },
    {
        "question": "What is the significance of the Golden eagle at the entrance?",
        "answer": "The Golden eagle is a symbol of freedom, loyalty, and courage."
    },
    {
        "question": "What is the purpose of the show 'dynamic layout of the Central part of modern Astana'?",
        "answer": "The show displays the chronological order of construction of attractions and residential complexes of the city of Astana."
    },
    {
        "question": "What modern exhibition technologies are used in the museum?",
        "answer": "The museum uses unique curved screens, media floors, dynamic layouts, media screens, holograms, LED technology, touch kiosks, multimedia guides, and other modern technologies."
    },
    {
        "question": "What types of excursions are offered at the museum?",
        "answer": "The museum offers thematic and sightseeing excursions, specialized excursions, philosophical excursions, game-based excursions, and interactive classes."
    },
    {
        "question": "What is the main goal of the museum?",
        "answer": "The main goal is to become a cradle of modern culture and a place for intellectual reflection on the historical and cultural heritage of Kazakhstan."
    },
    {
        "question": "What role do visitors play in the museum's approach?",
        "answer": "Visitors are considered active participants in the conversation with history, encouraging open dialogue."
    },
    {
        "question": "What makes the museum building unique?",
        "answer": "The building features unusual shapes and stunning architectural solutions, attracting thousands of tourists."
    },
    {
        "question": "How does the museum contribute to cultural preservation?",
        "answer": "The museum preserves the cultural heritage of Kazakhstan through its exhibitions and educational programs."
    },
    {
        "question": "What is the significance of the museum's location on Independence Square?",
        "answer": "The location symbolizes the museum's connection to the country's history and independence."
    },
    {
        "question": "What makes the museum the largest in Central Asia?",
        "answer": "The museum's extensive exhibition space and diverse collection make it the largest in Central Asia."
    },
    {
        "question": "How does the museum engage with children?",
        "answer": "The museum offers a children's museum, creative center, and interactive activities tailored for children."
    },
    {
        "question": "What is the symbolism behind the museum's architecture?",
        "answer": "The museum's architecture reflects the cultural and historical identity of Kazakhstan."
    },
    {
        "question": "How does the museum incorporate modern technology?",
        "answer": "The museum uses state-of-the-art technology for exhibits, displays, and interactive experiences."
    },
    {
        "question": "What cultural values are represented in the museum?",
        "answer": "The museum represents the diverse cultural heritage of Kazakhstan through its exhibitions."
    },
    {
        "question": "What is the significance of the museum's role in the community?",
        "answer": "The museum serves as a center for cultural and intellectual activities in the community."
    },
    {
        "question": "How does the museum contribute to tourism?",
        "answer": "The museum attracts tourists by showcasing Kazakhstan's rich history and culture."
    },
    {
        "question": "What educational resources are available at the museum?",
        "answer": "The museum offers a scientific library, educational programs, and interactive exhibits for learning."
    },
    {
        "question": "What values does the museum aim to promote?",
        "answer": "The museum aims to promote values such as cultural appreciation, intellectual inquiry, and historical awareness."
    },
    {
        "question": "What is the significance of the museum's layout?",
        "answer": "The layout of the museum allows for an immersive and interactive experience for visitors."
    },
    {
        "question": "How does the museum contribute to public understanding of history?",
        "answer": "The museum provides insights into Kazakhstan's history through its exhibitions and educational programs."
    },
    {
        "question": "What cultural events are hosted by the museum?",
        "answer": "The museum hosts cultural events such as exhibitions, workshops, and lectures."
    },
    {
        "question": "What is the museum's approach to historical interpretation?",
        "answer": "The museum offers a balanced and informative interpretation of Kazakhstan's history."
    },
    {
        "question": "What role does the museum play in promoting national identity?",
        "answer": "The museum serves as a platform for celebrating Kazakhstan's national identity and cultural heritage."
    },
    {
        "question": "How does the museum contribute to international cultural exchange?",
        "answer": "The museum facilitates cultural exchange through exhibitions, collaborations, and educational initiatives."
    },
    {
        "question": "What cultural themes are explored in the museum's exhibitions?",
        "answer": "The museum explores themes such as Kazakh traditions, history, art, and folklore."
    },
    {
        "question": "What is the significance of the museum's role in cultural heritage?",
        "answer": "The museum plays a crucial role in preserving and promoting Kazakhstan's cultural heritage for future generations."
    },
    {
        "question": "What makes the museum a significant landmark in Astana?",
        "answer": "The museum's architectural design and cultural importance make it a significant landmark in Astana."
    },
    {
        "question": "What is the museum's role in promoting cultural diversity?",
        "answer": "The museum celebrates Kazakhstan's cultural diversity through its exhibitions and programs."
    },
    {
        "question": "How does the museum contribute to lifelong learning?",
        "answer": "The museum offers educational resources and programs for visitors of all ages, promoting lifelong learning."
    },
    {
        "question": "What is the significance of the museum's role in shaping national memory?",
        "answer": "The museum helps shape national memory by preserving and presenting Kazakhstan's history and heritage."
    }
]

# %%
dataset_3 = [
    {
        "question": "What is the title of the landmark?",
        "answer": "The Palace of Peace and Reconciliation."
    },
    {
        "question": "Where is the landmark located?",
        "answer": "Астана, проспект Тауелсiздiк 57."
    },
    {
        "question": "What is the phone number of the landmark?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the landmark's webpage?",
        "answer": "https://astana.citypass.kz/en/2018/02/15/dvorets-mira-i-soglasiya/"
    },
    {
        "question": "Who proposed the idea of building the Palace of Peace and Reconciliation?",
        "answer": "The idea of rising the Palace of Peace and Reconciliation belongs to the President of the Republic Nursultan Nazarbayev."
    },
    {
        "question": "Who is the architect of the Palace of Peace and Reconciliation?",
        "answer": "The architect of the Palace of Peace and Reconciliation is British architect Norman Foster."
    },
    {
        "question": "What is depicted on the panel at the top of the pyramid?",
        "answer": "The panel at the top of the pyramid depicts 130 pigeons, symbolizing the people of Kazakhstan."
    },
    {
        "question": "When was the Palace of Peace and Reconciliation opened?",
        "answer": "The Palace of Peace and Reconciliation was opened in 2006."
    },
    {
        "question": "Who performed at the grand opening of the Palace of Peace and Reconciliation?",
        "answer": "The world opera star Monserrat Caballe performed at the grand opening."
    },
    {
        "question": "How many spectators can the concert hall of the palace hold?",
        "answer": "The concert hall of the palace can hold up to 1500 spectators."
    },
    {
        "question": "What facilities are available in the Palace of Peace and Reconciliation?",
        "answer": "The palace features conference halls, premises for events, exhibition halls, a center for contemporary art, and the 'Cheops Atrium.'"
    },
    {
        "question": "What events are organized in the exhibition halls?",
        "answer": "Temporary exhibitions and creative meetings are organized in the exhibition halls."
    },
    {
        "question": "What is located at the top of the pyramid?",
        "answer": "At the top of the pyramid is the 'Cradle' hall, which hosts congresses of world and traditional-national religions."
    },
    {
        "question": "How can visitors reach the top of the pyramid?",
        "answer": "Visitors can use panoramic elevators or climb stairs through hanging gardens to reach the top of the pyramid."
    },
    {
        "question": "What is special about the design of the pyramid?",
        "answer": "The pyramid is built on the principles of the 'Golden Section,' with a height equal to the length of the square at the bottom."
    },
    {
        "question": "What makes the landmark a symbol of unity?",
        "answer": "The Palace of Peace and Reconciliation became a symbol of unity for the residents of Astana and Kazakhstan."
    },
    {
        "question": "How does the landmark contribute to cultural exchange?",
        "answer": "The landmark hosts events that bring together artists from Kazakhstan and other countries, fostering cultural exchange."
    },
    {
        "question": "What is unique about the interior of the pyramid?",
        "answer": "The interior features interesting design solutions, including hanging gardens and panoramic views."
    },
    {
        "question": "What is the significance of the stained glass at night?",
        "answer": "At night, the illuminated stained glass top of the pyramid makes the building visible from various points in the capital."
    },
    {
        "question": "What message does the pyramid convey?",
        "answer": "The pyramid conveys a message of peace, reconciliation, and cultural harmony."
    },
    {
        "question": "How does the landmark contribute to tourism?",
        "answer": "The Palace of Peace and Reconciliation attracts tourists with its unique architecture and cultural significance."
    },
    {
        "question": "What role does the landmark play in hosting international events?",
        "answer": "The landmark hosts international congresses and events, promoting dialogue and cooperation among nations."
    },
    {
        "question": "What is the significance of the 'Cheops Atrium'?",
        "answer": "The 'Cheops Atrium' is the most grandiose premise of the palace, with an area of over 2000 sq.m."
    },
    {
        "question": "What does the pyramid symbolize?",
        "answer": "The pyramid symbolizes peace, reconciliation, and unity among nations."
    },
    {
        "question": "How does the landmark honor the people of Kazakhstan?",
        "answer": "The panel at the top of the pyramid depicts pigeons, symbolizing the people of Kazakhstan."
    },
    {
        "question": "What makes the landmark stand out among other buildings in Astana?",
        "answer": "The landmark's unique pyramid shape and cultural significance make it stand out among other buildings in Astana."
    },
    {
        "question": "What events are held in the conference halls?",
        "answer": "The conference halls host various events, including congresses, presentations, and meetings."
    },
    {
        "question": "What is the cultural significance of the landmark?",
        "answer": "The landmark promotes cultural exchange, dialogue, and understanding among diverse communities."
    },
    {
        "question": "How does the landmark contribute to the city's identity?",
        "answer": "The landmark is a symbol of the city's aspirations for peace, harmony, and cultural prosperity."
    },
    {
        "question": "What features make the landmark a tourist attraction?",
        "answer": "The unique architecture, panoramic views, and cultural events make the landmark a popular tourist attraction."
    },
    {
        "question": "What is the historical significance of the landmark?",
        "answer": "The landmark represents a modern architectural marvel and a symbol of Kazakhstan's commitment to peace and reconciliation."
    },
    {
        "question": "What is the cultural legacy of the landmark?",
        "answer": "The landmark contributes to Kazakhstan's cultural legacy by fostering cultural exchange and promoting dialogue among nations."
    },
    {
        "question": "How does the landmark contribute to national pride?",
        "answer": "The landmark symbolizes Kazakhstan's achievements and aspirations for a peaceful and harmonious future, instilling national pride."
    },
    {
        "question": "What is the significance of the landmark's name?",
        "answer": "The name 'Palace of Peace and Reconciliation' reflects the landmark's mission to promote peace and harmony."
    },
    {
        "question": "What is the cultural significance of the 'Cradle' hall?",
        "answer": "The 'Cradle' hall hosts congresses of world and traditional-national religions, promoting cultural understanding and cooperation."
    },
    {
        "question": "How does the landmark contribute to cultural diplomacy?",
        "answer": "The landmark serves as a venue for cultural events and international congresses, fostering cultural diplomacy and understanding."
    },
    {
        "question": "What is the architectural significance of the landmark?",
        "answer": "The landmark's pyramid shape and unique design reflect both aesthetic beauty and architectural innovation."
    },
    {
        "question": "What values does the landmark embody?",
        "answer": "The landmark embodies values of peace, reconciliation, unity, and cultural diversity."
    },
    {
        "question": "What is the educational role of the landmark?",
        "answer": "The landmark educates visitors about peace, cultural heritage, and the importance of dialogue and cooperation among nations."
    },
    {
        "question": "How does the landmark contribute to social cohesion?",
        "answer": "The landmark brings people together through cultural events, promoting social cohesion and understanding."
    },
    {
        "question": "What impact does the landmark have on the city's skyline?",
        "answer": "The landmark's illuminated top makes it a prominent feature of the city's skyline, especially at night."
    },
    {
        "question": "What future role does the landmark envision?",
        "answer": "The landmark aims to continue promoting peace, reconciliation, and cultural exchange, serving as a beacon of hope for future generations."
    }
]

# %%
dataset_2 = [
    {
        "question": "What is the title of the attraction?",
        "answer": "Theater of animatronics 'Jungle'."
    },
    {
        "question": "Where is the attraction located?",
        "answer": "г. Астана, Коргалжинское шоссе, 2."
    },
    {
        "question": "What is the phone number of the attraction?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the attraction's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/09/15/teatr-animatroniksov-dzhungli/"
    },
    {
        "question": "Who came up with the idea of creating the dinosaur Park?",
        "answer": "The idea of creating a one-of-a-kind dinosaur Park belonged to the first President of the Republic of Kazakhstan, N. A. Nazarbayev."
    },
    {
        "question": "When was the dinopark opened?",
        "answer": "The dinopark was opened on July 6, 2008, the day of the capital (Astana)."
    },
    {
        "question": "Who developed the animatronics robots for the dinopark?",
        "answer": "Animatronics robots for dinopark were developed and created in Kazakhstan by the domestic company 'Kazakhstan Salyut', with Vadim Gostev as the chief designer."
    },
    {
        "question": "What is the size of the dinopark?",
        "answer": "The dinopark occupies more than 3000 m2 of area."
    },
    {
        "question": "What can visitors expect to see in the dinopark?",
        "answer": "Visitors can expect to see a combination of theatrical performances, robot dinosaurs, water slides, and an exciting journey through the jungle."
    },
    {
        "question": "What atmosphere does the dinopark recreate?",
        "answer": "The dinopark recreates the atmosphere of the impenetrable jungle and the lost world of prehistoric animals."
    },
    {
        "question": "What is the theme of the animatronics theater?",
        "answer": "The theme of the animatronics theater is the jungle, with robotic dinosaurs and other prehistoric creatures."
    },
    {
        "question": "What are some of the attractions in the dinopark?",
        "answer": "Some attractions include encounters with robotic dinosaurs, giant spiders, crocodiles, frogs, and mythical creatures, as well as a journey through caves and over bridges."
    },
    {
        "question": "What awaits visitors at the entrance to the animatronics theater?",
        "answer": "Visitors are greeted by a huge stone face of an ancient deity that comes to life and leads them into the jungle."
    },
    {
        "question": "What is inside the cave in the dinopark?",
        "answer": "Inside the cave, visitors encounter giant spiders, crocodiles, and mythical creatures."
    },
    {
        "question": "What is the height of the Tyrannosaur figure?",
        "answer": "The Tyrannosaur figure is more than 3.5 meters tall."
    },
    {
        "question": "What can visitors observe after climbing the bridge?",
        "answer": "After climbing the bridge, visitors can observe the life of Pterodactyls and Diplodocus from a height."
    },
    {
        "question": "What is special about the cave of stalactites and stalagmites?",
        "answer": "The cave features stalactites, stalagmites, precious stones, and thousands of bats hiding under the vaults."
    },
    {
        "question": "What unfolds on the stage of the ancient amphitheater?",
        "answer": "Theatrical performances unfold on the stage of the ancient amphitheater in the mysterious city of ancient civilizations."
    },
    {
        "question": "What age group does the animatronics theater appeal to?",
        "answer": "The animatronics theater appeals to both children and adults."
    },
    {
        "question": "What company developed the animatronics robots?",
        "answer": "The domestic company 'Kazakhstan Salyut' developed the animatronics robots."
    },
    {
        "question": "What is the most memorable feature of the dinopark?",
        "answer": "The most memorable feature is the lifelike animatronics robots and the immersive jungle atmosphere."
    },
    {
        "question": "What makes the dinopark unique?",
        "answer": "The dinopark is unique for its combination of theatrical performances, robot dinosaurs, and water slides, all created domestically in Kazakhstan."
    },
    {
        "question": "How is the dinopark connected to the theme of the jungle?",
        "answer": "The dinopark recreates the atmosphere of the jungle with its flora, fauna, and prehistoric creatures."
    },
    {
        "question": "What role does theatrical performances play in the dinopark?",
        "answer": "Theatrical performances add to the immersive experience of the dinopark, enhancing the atmosphere and storytelling."
    },
    {
        "question": "What can visitors learn from their journey through the dinopark?",
        "answer": "Visitors can learn about prehistoric creatures, jungle habitats, and the mysteries of the lost world."
    },
    {
        "question": "How does the dinopark engage its visitors?",
        "answer": "The dinopark engages visitors through interactive experiences, guided tours, and storytelling."
    },
    {
        "question": "What is the architectural style of the dinopark building?",
        "answer": "The dinopark building is designed in a style that resembles a jungle temple or ancient ruins."
    },
    {
        "question": "What is the significance of the day when the dinopark opened?",
        "answer": "The dinopark opened on July 6, 2008, the day of the capital (Astana), making it a significant event for the city."
    },
    {
        "question": "What makes the dinopark an unforgettable experience?",
        "answer": "The combination of lifelike animatronics, immersive jungle atmosphere, and thrilling attractions makes the dinopark an unforgettable experience."
    },
    {
        "question": "How does the dinopark contribute to tourism in Astana?",
        "answer": "The dinopark attracts tourists with its unique offerings and adds to the diversity of attractions in Astana."
    },
    {
        "question": "What are some of the features of the animatronics robots?",
        "answer": "The animatronics robots are lifelike, with realistic movements and appearances, adding to the immersive experience of the dinopark."
    },
    {
        "question": "What is the main theme of the dinopark?",
        "answer": "The main theme of the dinopark is the exploration of the jungle and encounters with prehistoric creatures."
    },
    {
        "question": "What role do guides and animators play in the dinopark?",
        "answer": "Guides and animators provide informative tours and storytelling, enhancing the visitor experience."
    },
    {
        "question": "What is the size of the building housing the dinopark?",
        "answer": "The building housing the dinopark occupies more than 3000 m2 of area."
    },
    {
        "question": "What is the overall atmosphere of the dinopark?",
        "answer": "The overall atmosphere of the dinopark is mysterious, adventurous, and immersive, transporting visitors to a lost world."
    },
    {
        "question": "How do visitors enter the animatronics theater?",
        "answer": "Visitors enter the animatronics theater through a gap in a huge stone face of an ancient deity."
    },
    {
        "question": "What is the most impressive feature of the animatronics theater?",
        "answer": "The most impressive feature is the lifelike animatronics robots that interact with visitors and create a sense of wonder."
    },
    {
        "question": "What emotions does the dinopark evoke in visitors?",
        "answer": "The dinopark evokes a sense of excitement, wonder, and adventure in visitors of all ages."
    },
    {
        "question": "What is the significance of the animatronics robots being developed domestically?",
        "answer": "The fact that the animatronics robots were developed domestically adds to the uniqueness and pride associated with the dinopark."
    }
]

# %%
dataset_1 = [
    {
        "question": "What is the title of the attraction?",
        "answer": "«Nur-Alem» Future Energy Museum (EXPO)."
    },
    {
        "question": "Where is the attraction located?",
        "answer": "Астана, Орынбор , 55."
    },
    {
        "question": "What is the phone number of the attraction?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the attraction's webpage?",
        "answer": "https://astana.citypass.kz/en/2017/11/24/obektyi-naslediya-ekspo/"
    },
    {
        "question": "What is the main symbol of EXPO Nur-Sultan?",
        "answer": "The main symbol of EXPO Nur-Sultan is Nur-Alem, a giant spherical building with a diameter of 80 meters."
    },
    {
        "question": "What are located on top of the spherical building?",
        "answer": "Two wind generators are located on top of the spherical building."
    },
    {
        "question": "How many levels does the structure consist of?",
        "answer": "The structure consists of eight levels."
    },
    {
        "question": "What does each level of the structure tell about?",
        "answer": "Each level tells about one of the alternative energy sources, such as 'space Energy', 'Solar Energy', 'wind Energy', 'biomass Energy', 'Kinetic energy', and 'water Energy'."
    },
    {
        "question": "What is located on the eighth level?",
        "answer": "The Museum 'Future Nur-Sultan' is located on the eighth level."
    },
    {
        "question": "What is the area of the base of the sphere?",
        "answer": "The base of the sphere has an area of 5000 square meters."
    },
    {
        "question": "How much area does the national pavilion occupy?",
        "answer": "The national pavilion occupies a total of 500 meters."
    },
    {
        "question": "What are the two zones of the national pavilion?",
        "answer": "The two zones are 'acquaintance with Kazakhstan' and 'Creative energy'."
    },
    {
        "question": "What kind of projects are presented in the Museum of future energy?",
        "answer": "The Museum of future energy presents projects of scientists of Kazakhstan and startup projects of young specialists in the field of 'green' energy sources."
    },
    {
        "question": "What has been done to preserve the EXPO heritage?",
        "answer": "A lot of work has been done to preserve the EXPO heritage and promote the ideas of 'future Energy'."
    },
    {
        "question": "What facilities are included in the infrastructure of the attraction?",
        "answer": "The infrastructure includes a transport and logistics center, a communications Center, the office of the managing company JSC 'NC' EXPO Congress', and the building of the operational Department of internal Affairs."
    },
    {
        "question": "What is the price for tickets to the EXPO?",
        "answer": "The price for tickets to the EXPO is 1500 tenge."
    },
    {
        "question": "What engineering communications are located on the entire territory of the exhibition?",
        "answer": "All the necessary engineering communications such as water supply, power supply, Sewerage, WI-FI, etc. are located on the entire territory of the exhibition."
    },
    {
        "question": "What can visitors do on the territory of the EXPO?",
        "answer": "Visitors can enjoy an interesting tour of the EXPO heritage sites."
    },
    {
        "question": "What is the main focus of the exhibition?",
        "answer": "The main focus of the exhibition is on future energy and alternative energy sources."
    },
    {
        "question": "What makes the spherical building unique?",
        "answer": "The spherical building is unique for its innovative design and focus on sustainable energy."
    },
    {
        "question": "What type of power generators are installed on top of the spherical building?",
        "answer": "Two wind generators are installed on top of the spherical building."
    },
    {
        "question": "What is the size of the national pavilion?",
        "answer": "The national pavilion occupies a total of 500 meters."
    },
    {
        "question": "What kind of projects are presented in the national pavilion?",
        "answer": "The national pavilion presents projects related to the 'acquaintance with Kazakhstan' and 'Creative energy'."
    },
    {
        "question": "How is the Museum of future energy related to the overall theme of the exhibition?",
        "answer": "The Museum of future energy presents projects related to future energy and alternative energy sources, which are the main focus of the exhibition."
    },
    {
        "question": "What is the purpose of the transport and logistics center?",
        "answer": "The purpose of the transport and logistics center is to facilitate the movement of goods and people within the exhibition area."
    },
    {
        "question": "What role does the communications Center play?",
        "answer": "The communications Center serves as a hub for data processing, media broadcasting, and administrative functions."
    },
    {
        "question": "What is the significance of the EXPO exhibition?",
        "answer": "The EXPO exhibition is significant for promoting ideas of sustainable energy and preserving the EXPO heritage."
    },
    {
        "question": "What activities are regularly organized on the territory of the EXPO?",
        "answer": "Regular excursions are organized on the territory of the EXPO."
    },
    {
        "question": "How has the ticket pricing changed after the exhibition period?",
        "answer": "After the exhibition period, ticket prices have significantly decreased."
    },
    {
        "question": "What can visitors expect from an excursion to the EXPO heritage sites?",
        "answer": "Visitors can expect to learn about sustainable energy, explore innovative exhibits, and enjoy the unique atmosphere of the EXPO."
    },
    {
        "question": "What role does the Museum of future energy play in promoting green technologies?",
        "answer": "The Museum of future energy showcases projects and initiatives related to green technologies, promoting awareness and innovation in sustainable energy."
    },
    {
        "question": "What are some of the features of the spherical building?",
        "answer": "Some features of the spherical building include its unique design, wind generators on top, and its focus on showcasing alternative energy sources."
    },
    {
        "question": "What type of exhibitions are held in the national pavilion?",
        "answer": "The national pavilion hosts exhibitions related to Kazakhstan's culture, heritage, and innovative projects."
    },
    {
        "question": "How does the EXPO exhibition contribute to the local economy?",
        "answer": "The EXPO exhibition attracts tourists, fosters innovation, and promotes economic development through infrastructure projects and tourism."
    },
    {
        "question": "What is the significance of the EXPO exhibition for Kazakhstan?",
        "answer": "The EXPO exhibition serves as a platform to showcase Kazakhstan's achievements, promote sustainable development, and strengthen international cooperation."
    },
    {
        "question": "What is the main theme of the national pavilion?",
        "answer": "The main theme of the national pavilion is to introduce visitors to Kazakhstan's culture and creativity, as well as its contributions to sustainable energy."
    },
    {
        "question": "How does the spherical building contribute to reducing energy consumption?",
        "answer": "The spherical building incorporates wind generators on top, which generate power and reduce energy consumption from the grid."
    },
    {
        "question": "What type of exhibitions are held in the Museum of future energy?",
        "answer": "The Museum of future energy hosts exhibitions showcasing innovative projects and initiatives related to sustainable energy."
    },
    {
        "question": "What is the overall size of the exhibition area?",
        "answer": "The exhibition area covers a significant area, including the spherical building, national pavilion, and other facilities."
    },
    {
        "question": "How does the EXPO exhibition promote international cooperation?",
        "answer": "The EXPO exhibition serves as a platform for countries to exchange ideas, showcase innovations, and collaborate on global challenges such as sustainable development."
    },
    {
        "question": "What makes the Museum of future energy unique?",
        "answer": "The Museum of future energy is unique for its focus on showcasing cutting-edge projects and initiatives in the field of sustainable energy."
    }
]

# %%
dataset_0 = [
    {
        "question": "What is the title of the attraction?",
        "answer": "Ethno-memorial complex «Atameken»."
    },
    {
        "question": "Where is the attraction located?",
        "answer": "The attraction is located at Астана, Коргалжинское шоссе, 2/1."
    },
    {
        "question": "What is the phone number of the attraction?",
        "answer": "+7 (7172) 79-04-39."
    },
    {
        "question": "What is the link to the attraction's webpage?",
        "answer": "https://astana.citypass.kz/en/2018/07/17/etno-memorialnyiy-kompleks-atameken/"
    },
    {
        "question": "When was the ethno-memorial complex 'Atameken' opened?",
        "answer": "The ethno-memorial complex 'Atameken' was opened on September 8, 2001."
    },
    {
        "question": "Who initiated the opening of the ethno-memorial complex 'Atameken'?",
        "answer": "The opening of the ethno-memorial complex 'Atameken' was initiated by the first President of the Republic of Kazakhstan N. A. Nazarbayev."
    },
    {
        "question": "What is the objective of the Map of Kazakhstan 'Atameken'?",
        "answer": "The objective of the Map of Kazakhstan 'Atameken' is to ensure the safety, availability, and involvement of the population in historical, cultural, and spiritual values, as well as to propagate the achievements of Kazakh culture."
    },
    {
        "question": "What does the educational and artistic complex 'Map of Kazakhstan 'Atameken' introduce visitors to?",
        "answer": "The educational and artistic complex 'Map of Kazakhstan 'Atameken'' introduces visitors to the history of the state and the culture of its peoples."
    },
    {
        "question": "What are the components of the symbolic ensemble of the complex?",
        "answer": "The symbolic ensemble of the complex includes stylized mountains, hills, steppes, forests, lakes, and symbolically designated major cities."
    },
    {
        "question": "What interesting part is included in the Map of Kazakhstan 'Atameken'?",
        "answer": "An interesting part of the Map of Kazakhstan 'Atameken' is a decorative model of the Caspian Sea."
    },
    {
        "question": "What is the price for a tour in Kazakh language?",
        "answer": "The price for a tour in Kazakh language is 200 tenge."
    },
    {
        "question": "What is the price for a tour in Russian language?",
        "answer": "The price for a tour in Russian language is 200 tenge."
    },
    {
        "question": "What is the price for a tour in English language?",
        "answer": "The price for a tour in English language is 500 tenge."
    },
    {
        "question": "What is the price for photography?",
        "answer": "The price for photography is 300 tenge."
    },
    {
        "question": "Who can enter the complex for free and out of turn?",
        "answer": "Participants and invalids of the Second World War can enter the complex for free and out of turn upon presentation of supporting documents."
    },
    {
        "question": "Who else can enter the complex for free?",
        "answer": "Disabled people of group I, II, and children with disabilities under 18 years of age can enter the complex for free upon presentation of supporting documents."
    },
    {
        "question": "What discount do disabled people of group III get?",
        "answer": "Disabled people of group III get a 50% discount from the entrance ticket price upon presentation of supporting documents."
    },
    {
        "question": "Who else can enter the complex for free?",
        "answer": "Orphans and children left without parental care who have not reached the age of 18 can enter the complex for free upon presentation of supporting documents."
    },
    {
        "question": "What is the age limit for free entrance?",
        "answer": "Children under 5 (five) years old can enter the complex for free upon presentation of supporting documents."
    }
]

# %%
for i in range(16):
    for item in (locals()["dataset_" + str(i)]):
        item["type"] = i

# %%
dataset = []

for i in range(16):
    dataset.extend(locals()["dataset_" + str(i)])

# %%
with open('../datasets/about/data.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = ['question', 'answer', 'type']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    
    writer.writeheader()
    for data in dataset:
        writer.writerow({'question': data['question'], 'answer': data['answer'], 'type': data['type']})
